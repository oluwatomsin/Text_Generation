# %% [markdown]
# ## Loading Relevant Packages

# %%
import pandas as pd

# %% [markdown]
# ## Loading the dataset

# %%
# Loading the dataset
data = pd.read_pickle('corpus.pkl')
data.head()
# Out:
#                                                 transcript         full_name
# ali      Ladies and gentlemen, please welcome to the st...          Ali Wong
# anthony  Thank you. Thank you. Thank you, San Francisco...  Anthony Jeselnik
# bill     [cheers and applause] All right, thank you! Th...         Bill Burr
# bo       Bo What? Old MacDonald had a farm E I E I O An...        Bo Burnham
# dave     This is Dave. He tells dirty jokes for a livin...    Dave Chappelle

# %%
# Getting the number of comedian
print(f"The number of comdeians is {len(data.index.unique())}")
# Out:
# The number of comdeians is 12

# %%
# Observing the text
bill_burr = data.loc['bill'].transcript
bill_burr[:300]
# Out:
# '[cheers and applause] All right, thank you! Thank you very much! Thank you. Thank you. Thank you. How are you? What’s going on? Thank you. It’s a pleasure to be here in the greater Atlanta, Georgia, area, this oasis. It’s nice to be here. I don’t know why I came here in June. It’s nice to be here. W'

# %% [markdown]
# ## Data cleaning and preprocessing

# %%
import re # This is also a powerful text cleaning library


def text_cleaner(text):
    # Converting to lowercase
    text = text.lower()
    # Removing the texts in square brackets including the bracket
    text = re.sub(r"\[[^]]*\]", "", text)
    # Removing punctuation
    text = re.sub(r'[^\w\s]', '', text)
    # Removing numbers
    text = re.sub(r'[0-9]+', '', text)
    return text

# %%
bill_burr_cleaned = text_cleaner(bill_burr)
bill_burr_cleaned[:800]
# Out:
# ' all right thank you thank you very much thank you thank you thank you how are you whats going on thank you its a pleasure to be here in the greater atlanta georgia area this oasis its nice to be here i dont know why i came here in june its nice to be here wasnt thinking fucking ridiculously hot out there just miserable horrible that kind of heat you understand the racism down here ya know i get it how would you get along with anybody look at em just over there drinkin a cold drink lemonade was made for the white man so what the hell have i been doing with my life trying to get in shape man but i hate going to the gym so i decided id go veggie twice a week its brutal i can only make it till about  five oclock thats what i realized about myself you know that something has to die every day i'

# %% [markdown]
# ## Building the markov function

# %%
from collections import defaultdict

# %%
def markov(text):
    # Splitting the text
    words = text.split()
    # Creating a default dictionary that accepts a list as the input
    dicts = defaultdict(list)
    # Creating a dictionary with current word as the key and appending the next word into the values list 
    # With this, all the unique words in the text corpus becomes a key.
    for current_word, next_word in zip(words[:-1], words[1:]):
        dicts[current_word].append(next_word)
    m_dict = dict(dicts)
    return m_dict

# %%
bills = markov(bill_burr_cleaned)
bills
# Out:
# {'all': ['right',
#   'that',
#   'this',
#   'these',
#   'right',
#   'of',
#   'kinds',
#   'of',
#   'of',
#   'right',
#   'right',
#   'you',
#   'pissed',
#   'you',
#   'over',
#   'through',
#   'right',
#   'right',
#   'of',
#   'comes',
#   'right',
#   'those',
#   'of',
#   'empty',
#   'right',
#   'dead',
#   'right',
#   'the',
#   'makes',
#   'of',
#   'right',
#   'the',
#   'of',
#   'night',
#   'right',
#   'my',
#   'these',
#   'of',
#   'right',
#   'of',
#   'of',
#   'of',
#   'car',
#   'right',
#   'the',
#   'six',
#   'right',
#   'great',
#   'youre',
#   'of',
#   'my',
#   'right',
#   'he',
#   'the',
#   'right',
#   'got',
#   'had',
#   'of',
#   'my',
#   'right',
#   'right',
#   'their',
#   'i',
#   'right',
#   'day',
#   'right',
#   'night',
#   'right',
#   'right',
#   'right',
#   'right',
#   'right',
#   'over',
#   'right',
#   'right',
#   'you',
#   'right',
#   'of',
#   'over',
#   'went',
#   'right',
#   'right',
#   'right',
#   'right',
#   'i',
#   'i',
#   'you',
#   'you',
#   'you',
#   'right',
#   'right',
#   'i',
#   'right',
#   'right',
#   'you',
#   'the',
#   'of',
#   'of',
#   'right',
#   'right',
#   'right',
#   'right',
#   'right',
#   'right',
#   'right',
#   'right',
#   'around',
#   'she',
#   'shes',
#   'right',
#   'right',
#   'the',
#   'right'],
#  'right': ['thank',
#   'they',
#   'theyre',
#   'they',
#   'cant',
#   'fuck',
#   'who',
#   'thats',
#   'now',
#   'now',
#   'so',
#   'that',
#   'yeah',
#   'im',
#   'dude',
#   'thats',
#   'around',
#   'you',
#   'ill',
#   'put',
#   'ranked',
#   'and',
#   'i',
#   'i',
#   'thats',
#   'ill',
#   'and',
#   'yours',
#   'i',
#   'why',
#   'hey',
#   'and',
#   'that',
#   'but',
#   'see',
#   'but',
#   'i',
#   'look',
#   'we',
#   'when',
#   'ah',
#   'and',
#   'and',
#   'with',
#   'just',
#   'just',
#   'now',
#   'god',
#   'here',
#   'lets',
#   'just',
#   'and',
#   'jesus',
#   'well',
#   'big',
#   'a',
#   'hes',
#   'so',
#   'now',
#   'now',
#   'youll',
#   'stay',
#   'out',
#   'come',
#   'and',
#   'hes',
#   'and',
#   'over',
#   'all',
#   'i',
#   'mine',
#   'id',
#   'coming',
#   'shit',
#   'i',
#   'i',
#   'yeah',
#   'oh',
#   'all',
#   'youre',
#   'stop',
#   'you',
#   'youre',
#   'now',
#   'the',
#   'out',
#   'i',
#   'thought',
#   'down',
#   'dad',
#   'this',
#   'so',
#   'if',
#   'handful',
#   'over',
#   'so',
#   'what',
#   'you',
#   'you',
#   'you',
#   'you',
#   'so',
#   'lets',
#   'so',
#   'you',
#   'for',
#   'thats',
#   'before',
#   'your',
#   'right',
#   'there',
#   'one',
#   'he',
#   'no',
#   'im',
#   'hey',
#   'no',
#   'all',
#   'all',
#   'tapping',
#   'im',
#   'in',
#   'im',
#   'just',
#   'i',
#   'cause',
#   'here',
#   'but',
#   'if',
#   'this',
#   'im'],
#  'thank': ['you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'god',
#   'you',
#   'you',
#   'you',
#   'you'],
#  'you': ['thank',
#   'very',
#   'thank',
#   'thank',
#   'how',
#   'whats',
#   'its',
#   'understand',
#   'get',
#   'know',
#   'know',
#   'know',
#   'have',
#   'need',
#   'cant',
#   'this',
#   'did',
#   'cant',
#   'got',
#   'got',
#   'gotta',
#   'and',
#   'got',
#   'know',
#   'get',
#   'dont',
#   'know',
#   'something',
#   'need',
#   'take',
#   'cant',
#   'honestly',
#   'ever',
#   'know',
#   'cant',
#   'telling',
#   'know',
#   'think',
#   'guys',
#   'ever',
#   'want',
#   'to',
#   'to',
#   'know',
#   'want',
#   'know',
#   'got',
#   'know',
#   'know',
#   'know',
#   'think',
#   'never',
#   'think',
#   'people',
#   'for',
#   'go',
#   'can',
#   'can',
#   'can',
#   'understand',
#   'know',
#   'people',
#   'think',
#   'know',
#   'you',
#   'can',
#   'can',
#   'you',
#   'wear',
#   'know',
#   'can',
#   'can',
#   'know',
#   'something',
#   'stay',
#   'stay',
#   'by',
#   'just',
#   'got',
#   'can',
#   'know',
#   'get',
#   'have',
#   'dont',
#   'have',
#   'get',
#   'dont',
#   'go',
#   'get',
#   'by',
#   'know',
#   'know',
#   'dressed',
#   'sung',
#   'had',
#   'know',
#   'want',
#   'can',
#   'have',
#   'put',
#   'cant',
#   'believe',
#   'seriously',
#   'think',
#   'think',
#   'thought',
#   'know',
#   'know',
#   'know',
#   'you',
#   'know',
#   'they',
#   'come',
#   'say',
#   'can',
#   'repeat',
#   'get',
#   'go',
#   'get',
#   'call',
#   'please',
#   'know',
#   'know',
#   'know',
#   'know',
#   'know',
#   'can',
#   'clear',
#   'know',
#   'know',
#   'know',
#   'know',
#   'know',
#   'know',
#   'call',
#   'think',
#   'know',
#   'die',
#   'die',
#   'go',
#   'made',
#   'know',
#   'give',
#   'make',
#   'have',
#   'dont',
#   'set',
#   'got',
#   'evil',
#   'im',
#   'out',
#   'know',
#   'can',
#   'just',
#   'think',
#   'to',
#   'came',
#   'come',
#   'gonna',
#   'die',
#   'wrap',
#   'were',
#   'remember',
#   'know',
#   'like',
#   'do',
#   'know',
#   'fly',
#   'land',
#   'bring',
#   'do',
#   'do',
#   'up',
#   'can',
#   'shut',
#   'have',
#   'know',
#   'think',
#   'and',
#   'know',
#   'know',
#   'remember',
#   'watched',
#   'mean',
#   'want',
#   'had',
#   'none',
#   'that',
#   'your',
#   'know',
#   'got',
#   'shack',
#   'when',
#   'know',
#   'know',
#   'guys',
#   'got',
#   'are',
#   'can',
#   'got',
#   'got',
#   'you',
#   'got',
#   'can',
#   'got',
#   'guys',
#   'get',
#   'ever',
#   'kids',
#   'were',
#   'gay',
#   'were',
#   'dont',
#   'hug',
#   'that',
#   'start',
#   'have',
#   'have',
#   'want',
#   'want',
#   'want',
#   'want',
#   'shitty',
#   'still',
#   'shit',
#   'go',
#   'wait',
#   'know',
#   'turn',
#   'grab',
#   'say',
#   'ever',
#   'guys',
#   'know',
#   'dont',
#   'dont',
#   'got',
#   'have',
#   'know',
#   'know',
#   'redo',
#   'got',
#   'got',
#   'what',
#   'dont',
#   'know',
#   'little',
#   'doing',
#   'keep',
#   'youre',
#   'gotta',
#   'cant',
#   'i',
#   'too',
#   'want',
#   'youve',
#   'say',
#   'do',
#   'say',
#   'know',
#   'want',
#   'you',
#   'know',
#   'want',
#   'sew',
#   'sew',
#   'understand',
#   'fuck',
#   'he',
#   'wanted',
#   'one',
#   'i',
#   'cant',
#   'just',
#   'feeling',
#   'feeling',
#   'know',
#   'know',
#   'go',
#   'gonna',
#   'guys',
#   'dont',
#   'slam',
#   'gotta',
#   'just',
#   'could',
#   'said',
#   'already',
#   'waiting',
#   'guys',
#   'go',
#   'all',
#   'son',
#   'look',
#   'doing',
#   'really',
#   'disease',
#   'go',
#   'know',
#   'got',
#   'think',
#   'want',
#   'guys',
#   'gun',
#   'keep',
#   'do',
#   'need',
#   'fucking',
#   'this',
#   'guys',
#   'ever',
#   'ever',
#   'take',
#   'put',
#   'got',
#   'look',
#   'put',
#   'ever',
#   'want',
#   'know',
#   'guys',
#   'got',
#   'have',
#   'got',
#   'gun',
#   'got',
#   'hear',
#   'barking',
#   'hear',
#   'just',
#   'pick',
#   'fucking',
#   'miss',
#   'cant',
#   'cant',
#   'gonna',
#   'see',
#   'had',
#   'could',
#   'could',
#   'could',
#   'guys',
#   'people',
#   'actually',
#   'have',
#   'pull',
#   'are',
#   'with',
#   'have',
#   'in',
#   'just',
#   'can',
#   'can',
#   'can',
#   'out',
#   'gonna',
#   'gonna',
#   'ill',
#   'dont',
#   'dont',
#   'got',
#   'talk',
#   'know',
#   'get',
#   'afraid',
#   'say',
#   'onto',
#   'got',
#   'got',
#   'well',
#   'in',
#   'out',
#   'wake',
#   'so',
#   'got',
#   'cant',
#   'only',
#   'got',
#   'got',
#   'just',
#   'do',
#   'just',
#   'bark',
#   'got',
#   'really',
#   'doing',
#   'want',
#   'got',
#   'just',
#   'got',
#   'could',
#   'getting',
#   'stop',
#   'see',
#   'dont',
#   'slowly',
#   'guys',
#   'so',
#   'thank',
#   'i',
#   'next'],
#  'very': ['much', 'offensive', 'happy', 'happy', 'least', 'interesting'],
#  'much': ['thank', 'as', 'as', 'every', 'thank'],
#  'how': ['are',
#   'would',
#   'does',
#   'they',
#   'i',
#   'we',
#   'the',
#   'am',
#   'is',
#   'is',
#   'do',
#   'scared',
#   'you',
#   'does',
#   'was',
#   'other',
#   'come',
#   'come',
#   'to',
#   'you',
#   'easy',
#   'easy',
#   'fucked',
#   'to',
#   'many',
#   'many',
#   'elated',
#   'to',
#   'it',
#   'tough',
#   'that',
#   'did',
#   'is'],
#  'are': ['you',
#   'up',
#   'you',
#   'doing',
#   'they',
#   'into',
#   'into',
#   'getting',
#   'right',
#   'like',
#   'you',
#   'fake',
#   'cunts',
#   'they',
#   'you',
#   'ruining',
#   'you',
#   'cool',
#   'all',
#   'you',
#   'you',
#   'out',
#   'gonna',
#   'you',
#   'you',
#   'i',
#   'you',
#   'you',
#   'you',
#   'awesome',
#   'awesome',
#   'you',
#   'burning'],
#  'whats': ['going',
#   'going',
#   'up',
#   'wrong',
#   'gonna',
#   'left',
#   'up',
#   'going',
#   'with',
#   'gonna',
#   'funny',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'come',
#   'the',
#   'the'],
#  'going': ['on',
#   'to',
#   'to',
#   'on',
#   'you',
#   'to',
#   'and',
#   'this',
#   'around',
#   'everybody',
#   'over',
#   'a',
#   'great',
#   'whoo',
#   'out',
#   'how',
#   'to',
#   'on',
#   'to',
#   'to',
#   'like',
#   'back',
#   'on',
#   'to',
#   'the',
#   'its'],
#  'on': ['thank',
#   'right',
#   'his',
#   'a',
#   'that',
#   'facebook',
#   'hitting',
#   'theyre',
#   'the',
#   'this',
#   'duck',
#   'that',
#   'instagram',
#   'instagram',
#   'out',
#   'dude',
#   'ninety',
#   'in',
#   'a',
#   'that',
#   'samesex',
#   'your',
#   'with',
#   'sundays',
#   'a',
#   'right',
#   'water',
#   'base',
#   'the',
#   'me',
#   'fire',
#   'a',
#   'my',
#   'it',
#   'that',
#   'it',
#   'the',
#   'too',
#   'a',
#   'good',
#   'your',
#   'his',
#   'his',
#   'around',
#   'paws',
#   'man',
#   'a',
#   'bring',
#   'the',
#   'cricket',
#   'the',
#   'the',
#   'we',
#   'the',
#   'this',
#   'miles',
#   'this',
#   'that',
#   'the',
#   'established',
#   'the',
#   'that',
#   'that',
#   'the',
#   'take',
#   'a',
#   'that',
#   'a',
#   'the',
#   'the',
#   'man',
#   'them',
#   'your',
#   'the',
#   'the',
#   'the',
#   'with',
#   'the',
#   'your',
#   'one'],
#  'its': ['a',
#   'nice',
#   'nice',
#   'brutal',
#   'beak',
#   'feathers',
#   'jaw',
#   'awful',
#   'an',
#   'like',
#   'a',
#   'a',
#   'a',
#   'like',
#   'horrific',
#   'over',
#   'shitting',
#   'one',
#   'not',
#   'gay',
#   'nothing',
#   'cause',
#   'your',
#   'like',
#   'like',
#   'nuts',
#   'fucking',
#   'been',
#   'just',
#   'not',
#   'a',
#   'all',
#   'so',
#   'just',
#   'gonna',
#   'like',
#   'just',
#   'an',
#   'too',
#   'kind',
#   'like',
#   'a',
#   'a',
#   'like',
#   'like',
#   'cause',
#   'an',
#   'just',
#   'the',
#   'so',
#   'not',
#   'gonna',
#   'a',
#   'one',
#   'like',
#   'like',
#   'fuckin',
#   'been',
#   'like',
#   'not',
#   'the',
#   'basically',
#   'an',
#   'like',
#   'like',
#   'the',
#   'supporting',
#   'a',
#   'not',
#   'in',
#   'ridiculous',
#   'like'],
#  'a': ['pleasure',
#   'cold',
#   'week',
#   'row',
#   'democracy',
#   'democracy',
#   'program',
#   'multiple',
#   'pencil',
#   'group',
#   'shit',
#   'group',
#   'group',
#   'fucking',
#   'fucking',
#   'quarterback',
#   'graduation',
#   'member',
#   'blessing',
#   'great',
#   'santa',
#   'flag',
#   'dick',
#   'bunch',
#   'gig',
#   'piece',
#   'great',
#   'perfect',
#   'shit',
#   'beer',
#   'picture',
#   'sudden',
#   'woman',
#   'woman',
#   'woman',
#   'minute',
#   'pledge',
#   'pledge',
#   'lot',
#   'holocaust',
#   'grandparent',
#   'sudden',
#   'snowman',
#   'water',
#   'fuck',
#   'half',
#   'half',
#   'line',
#   'catch',
#   'great',
#   'great',
#   'ballgame',
#   'b',
#   'fence',
#   'known',
#   'shit',
#   'castle',
#   'hippie',
#   'couple',
#   'serial',
#   'year',
#   'mike',
#   'college',
#   'senior',
#   'reference',
#   'kid',
#   'woman',
#   'shit',
#   'sports',
#   'really',
#   'dude',
#   'sports',
#   'dickless',
#   'woman',
#   'flashlight',
#   'fucking',
#   'benefit',
#   'beard',
#   'boat',
#   'swamp',
#   'little',
#   'jelly',
#   'star',
#   'big',
#   'masters',
#   'zillion',
#   'good',
#   'boat',
#   'group',
#   'whatever',
#   'wall',
#   'long',
#   'plane',
#   'bunch',
#   'lot',
#   'drivers',
#   'religion',
#   'woman',
#   'baby',
#   'spaceship',
#   'lot',
#   'tooth',
#   'fairy',
#   'decision',
#   'couple',
#   'year',
#   'team',
#   'sudden',
#   'riot',
#   'gig',
#   'pigeon',
#   'car',
#   'car',
#   'real',
#   'lot',
#   'damn',
#   'fuck',
#   'fear',
#   'fear',
#   'sudden',
#   'while',
#   'while',
#   'jet',
#   'little',
#   'war',
#   'joke',
#   'bunch',
#   'fuck',
#   'stud',
#   'city',
#   'smaller',
#   'sudden',
#   'sudden',
#   'vengeance',
#   'sudden',
#   'female',
#   'child',
#   'yearold',
#   'higher',
#   'man',
#   'haunted',
#   'species',
#   'safety',
#   'lion',
#   'sweater',
#   'guy',
#   'child',
#   'good',
#   'little',
#   'family',
#   'touchyfeely',
#   'marriage',
#   'great',
#   'split',
#   'kid',
#   'kid',
#   'veteran',
#   'kid',
#   'homophobic',
#   'drama',
#   'public',
#   'puddle',
#   'lot',
#   'little',
#   'sudden',
#   'kid',
#   'kid',
#   'frisbee',
#   'saturday',
#   'face',
#   'couple',
#   'kid',
#   'twoyearold',
#   'mitten',
#   'more',
#   'great',
#   'funny',
#   'great',
#   'sweatshop',
#   'seat',
#   'cloud',
#   'cloud',
#   'bowl',
#   'twofer',
#   'flamethrower',
#   'vacuum',
#   'toaster',
#   'big',
#   'couple',
#   'little',
#   'helicopter',
#   'skyscraper',
#   'house',
#   'gun',
#   'fucking',
#   'city',
#   'desert',
#   'birdbath',
#   'good',
#   'hover',
#   'helicopter',
#   'place',
#   'white',
#   'nail',
#   'mattress',
#   'sudden',
#   'mattress',
#   'tour',
#   'couple',
#   'tour',
#   'county',
#   'hero',
#   'romantic',
#   'man',
#   'chopper',
#   'superhero',
#   'fucking',
#   'burger',
#   'beer',
#   'county',
#   'dummy',
#   'hell',
#   'helicopter',
#   'happy',
#   'gun',
#   'helicopter',
#   'thats',
#   'whats',
#   'big',
#   'second',
#   'fiveshot',
#   'burnedout',
#   'couple',
#   'comedy',
#   'real',
#   'fucking',
#   'stranger',
#   'weapon',
#   'burnedout',
#   'gun',
#   'kick',
#   'nightstand',
#   'pork',
#   'fucking',
#   'sudden',
#   'sudden',
#   'fuckin',
#   'is',
#   'roidedup',
#   'jab',
#   'bb',
#   'fuck',
#   'bb',
#   'fact',
#   'fact',
#   'fight',
#   'blanket',
#   'bra',
#   'ball',
#   'debate',
#   'normal',
#   'ledge',
#   'chain',
#   'sandwich',
#   'neverending',
#   'fuck',
#   'dick',
#   'while',
#   'little',
#   'rescue',
#   'great',
#   'good',
#   'little',
#   'lot',
#   'little',
#   'romantic',
#   'womans',
#   'little',
#   'woman',
#   'little',
#   'little',
#   'passedout',
#   'while',
#   'wall',
#   'lot',
#   'metaphor',
#   'little',
#   'ushaped',
#   'doorjamb',
#   'porn',
#   'dick',
#   'buck',
#   'naked',
#   'halffilled',
#   'great'],
#  'pleasure': ['to'],
#  'to': ['be',
#   'be',
#   'be',
#   'get',
#   'the',
#   'die',
#   'live',
#   'get',
#   'its',
#   'survive',
#   'come',
#   'go',
#   'have',
#   'bring',
#   'immediately',
#   'be',
#   'be',
#   'people',
#   'say',
#   'meetings',
#   'improve',
#   'a',
#   'sit',
#   'thank',
#   'do',
#   'ruin',
#   'em',
#   'tell',
#   'take',
#   'watch',
#   'hit',
#   'open',
#   'have',
#   'have',
#   'have',
#   'use',
#   'blow',
#   'a',
#   'the',
#   'that',
#   'it',
#   'a',
#   'peter',
#   'chris',
#   'god',
#   'absorb',
#   'pay',
#   'whats',
#   'get',
#   'your',
#   'figure',
#   'be',
#   'the',
#   'color',
#   'switch',
#   'me',
#   'his',
#   'they',
#   'fucking',
#   'he',
#   'sunday',
#   'your',
#   'my',
#   'college',
#   'be',
#   'go',
#   'church',
#   'be',
#   'make',
#   'be',
#   'the',
#   'me',
#   'in',
#   'me',
#   'fall',
#   'make',
#   'it',
#   'me',
#   'town',
#   'anybody',
#   'believe',
#   'find',
#   'be',
#   'get',
#   'turn',
#   'fail',
#   'now',
#   'get',
#   'look',
#   'heaven',
#   'enjoy',
#   'show',
#   'enjoy',
#   'come',
#   'be',
#   'do',
#   'people',
#   'getting',
#   'make',
#   'so',
#   'a',
#   'turn',
#   'join',
#   'be',
#   'getting',
#   'build',
#   'have',
#   'just',
#   'an',
#   'me',
#   'bake',
#   'know',
#   'tell',
#   'stop',
#   'do',
#   'do',
#   'find',
#   'do',
#   'fucking',
#   'so',
#   'like',
#   'life',
#   'this',
#   'like',
#   'shout',
#   'think',
#   'hug',
#   'raise',
#   'tell',
#   'some',
#   'do',
#   'improve',
#   'keep',
#   'get',
#   'war',
#   'dont',
#   'like',
#   'drama',
#   'one',
#   'the',
#   'be',
#   'the',
#   'do',
#   'find',
#   'find',
#   'my',
#   'be',
#   'start',
#   'his',
#   'death',
#   'atlanta',
#   'get',
#   'parties',
#   'stop',
#   'me',
#   'have',
#   'do',
#   'use',
#   'get',
#   'be',
#   'adopt',
#   'do',
#   'piss',
#   'just',
#   'tell',
#   'do',
#   'get',
#   'get',
#   'do',
#   'rescue',
#   'the',
#   'raise',
#   'sit',
#   'me',
#   'be',
#   'go',
#   'say',
#   'you',
#   'know',
#   'make',
#   'himself',
#   'do',
#   'learn',
#   'fly',
#   'a',
#   'a',
#   'go',
#   'fly',
#   'do',
#   'achieve',
#   'ask',
#   'tell',
#   'god',
#   'his',
#   'give',
#   'a',
#   'this',
#   'open',
#   'do',
#   'be',
#   'him',
#   'get',
#   'get',
#   'pick',
#   'fly',
#   'do',
#   'the',
#   'be',
#   'go',
#   'the',
#   'go',
#   'squeak',
#   'go',
#   'work',
#   'you',
#   'kill',
#   'basically',
#   'somebodys',
#   'go',
#   'get',
#   'dial',
#   'sprinkle',
#   'figure',
#   'what',
#   'get',
#   'sleep',
#   'sleep',
#   'sleep',
#   'sleep',
#   'say',
#   'that',
#   'them',
#   'sleep',
#   'sleep',
#   'shes',
#   'be',
#   'keep',
#   'have',
#   'keep',
#   'people',
#   'people',
#   'her',
#   'make',
#   'feel',
#   'be',
#   'that',
#   'understand',
#   'get',
#   'choke',
#   'be',
#   'do',
#   'do',
#   'god',
#   'no',
#   'the',
#   'hell',
#   'bring',
#   'make',
#   'grab',
#   'try',
#   'pick',
#   'come',
#   'do',
#   'do',
#   'try',
#   'be',
#   'god',
#   'counterbalance',
#   'the',
#   'carry',
#   'carry',
#   'it',
#   'your'],
#  'be': ['here',
#   'here',
#   'here',
#   'great',
#   'if',
#   'honest',
#   'arbitrary',
#   'nice',
#   'fuckin',
#   'wait',
#   'honest',
#   'a',
#   'that',
#   'a',
#   'wrong',
#   'an',
#   'honest',
#   'honest',
#   'fair',
#   'some',
#   'that',
#   'like',
#   'openminded',
#   'the',
#   'even',
#   'like',
#   'honest',
#   'in',
#   'like',
#   'a',
#   'about',
#   'mad',
#   'animals',
#   'screaming',
#   'driving',
#   'like',
#   'in',
#   'like',
#   'the',
#   'like',
#   'an',
#   'bicoastal',
#   'like',
#   'brandnew',
#   'amazing',
#   'to',
#   'like',
#   'like',
#   'the',
#   'honest',
#   'nuts',
#   'crazy',
#   'like',
#   'like',
#   'enough',
#   'thinking',
#   'that',
#   'hang',
#   'a',
#   'one',
#   'shooting',
#   'ringing',
#   'throwing',
#   'the',
#   'that',
#   'hey',
#   'moody',
#   'mad',
#   'a',
#   'safe',
#   'getting',
#   'fun',
#   'a'],
#  'here': ['in',
#   'i',
#   'in',
#   'wasnt',
#   'ya',
#   'have',
#   'make',
#   'he',
#   'what',
#   'i',
#   'comes',
#   'i',
#   'and',
#   'mind',
#   'waiting',
#   'why',
#   'i',
#   'im',
#   'what',
#   'thinking',
#   'i',
#   'to',
#   'because',
#   'you',
#   'i',
#   'to',
#   'in',
#   'you',
#   'staring',
#   'and',
#   'meanwhile',
#   'downstairs',
#   'where',
#   'someone',
#   'she',
#   'thats',
#   'i',
#   'officer',
#   'is',
#   'fuckin'],
#  'in': ['the',
#   'june',
#   'shape',
#   'order',
#   'order',
#   'the',
#   'a',
#   'a',
#   'a',
#   'trouble',
#   'your',
#   'this',
#   'his',
#   'trouble',
#   'dallas',
#   'they',
#   'their',
#   'read',
#   'trouble',
#   'trouble',
#   'trouble',
#   'trouble',
#   'defense',
#   'ze',
#   'trouble',
#   'trouble',
#   'trouble',
#   'my',
#   'thats',
#   'to',
#   'the',
#   'the',
#   'the',
#   'the',
#   'that',
#   'your',
#   'trouble',
#   'black',
#   'it',
#   'trouble',
#   'my',
#   'the',
#   'the',
#   'vegas',
#   'case',
#   'a',
#   'the',
#   'there',
#   'like',
#   'english',
#   'a',
#   'the',
#   'los',
#   'my',
#   'the',
#   'and',
#   'theirs',
#   'this',
#   'curling',
#   'fulfillment',
#   'this',
#   'any',
#   'something',
#   'helsinki',
#   'the',
#   'the',
#   'you',
#   'that',
#   'here',
#   'here',
#   'the',
#   'the',
#   'a',
#   'a',
#   'its',
#   'the',
#   'my',
#   'the',
#   'love',
#   'the',
#   'you',
#   'love',
#   'reality',
#   'the',
#   'the',
#   'third',
#   'the',
#   'there',
#   'the',
#   'a',
#   'the',
#   'my',
#   'like',
#   'fifth',
#   'a',
#   'bring',
#   'you',
#   'the',
#   'the',
#   'wars',
#   'there',
#   'the',
#   'the',
#   'give',
#   'los',
#   'that',
#   'a',
#   'atlanta',
#   'atlanta',
#   'a',
#   'a',
#   'a',
#   'the',
#   'now',
#   'on',
#   'orange',
#   'orange',
#   'hes',
#   'five',
#   'from',
#   'sir',
#   'so',
#   'pain',
#   'my',
#   'an',
#   'a',
#   'the',
#   'sir',
#   'like',
#   'the',
#   'put',
#   'there',
#   'youre',
#   'the',
#   'the',
#   'too',
#   'in',
#   'the',
#   'minutes',
#   'the',
#   'so',
#   'the',
#   'through',
#   'a',
#   'this',
#   'your',
#   'my',
#   'me',
#   'my',
#   'bed',
#   'the',
#   'an',
#   'front',
#   'your',
#   'the',
#   'a',
#   'romantic',
#   'here',
#   'those',
#   'a',
#   'her',
#   'try',
#   'the',
#   'here',
#   'your',
#   'your',
#   'your'],
#  'the': ['greater',
#   'racism',
#   'white',
#   'hell',
#   'gym',
#   'hell',
#   'environment',
#   'gas',
#   'atmosphere',
#   'air',
#   'balls',
#   'population',
#   'balls',
#   'votes',
#   'sheer',
#   'fuck',
#   'same',
#   'gay',
#   'draft',
#   'jets',
#   'whole',
#   'next',
#   'buffalo',
#   'same',
#   'last',
#   'entire',
#   'way',
#   'manager',
#   'manager',
#   'waitress',
#   'dumbest',
#   'dont',
#   'church',
#   'nerve',
#   'amount',
#   'cookies',
#   'food',
#   'hell',
#   'old',
#   'old',
#   'owner',
#   'clippers',
#   'wrong',
#   'cookies',
#   'fuck',
#   'n',
#   'n',
#   'weirdest',
#   'guy',
#   'math',
#   'color',
#   'generation',
#   'genocide',
#   'native',
#   'owner',
#   'clippers',
#   'early',
#   's',
#   'bubble',
#   'world',
#   'place',
#   'last',
#   'bubble',
#   'sad',
#   'gig',
#   'devil',
#   'guitar',
#   'fucking',
#   'tennis',
#   'world',
#   'shit',
#   'shock',
#   'doubt',
#   'middle',
#   'church',
#   'book',
#   'language',
#   'church',
#   'church',
#   'good',
#   'bad',
#   'fucking',
#   'new',
#   'hell',
#   'manchurian',
#   'queers',
#   'fuck',
#   'fuck',
#   'old',
#   'boat',
#   'people',
#   'book',
#   'vatican',
#   'other',
#   'stories',
#   'dude',
#   'same',
#   'other',
#   'basis',
#   'ten',
#   'fifth',
#   'murderous',
#   'ankles',
#   'whole',
#   'whole',
#   'whole',
#   'stories',
#   'first',
#   'story',
#   'dumbest',
#   'mystery',
#   'scientologists',
#   'dumbest',
#   'space',
#   'chimney',
#   'easter',
#   'lake',
#   'tooth',
#   'nba',
#   'world',
#   'casual',
#   'time',
#   'shit',
#   'shooter',
#   'ride',
#   'two',
#   'third',
#   'scriptures',
#   'dvd',
#   'most',
#   'fact',
#   'rails',
#   'balls',
#   'engine',
#   'battery',
#   'way',
#   'deal',
#   'hell',
#   'bosss',
#   'worst',
#   'guys',
#   'plane',
#   'planes',
#   'pilots',
#   'airline',
#   'airline',
#   'fuckin',
#   'back',
#   'metal',
#   'planes',
#   'hair',
#   'shit',
#   'balls',
#   'fuck',
#   'day',
#   'discovery',
#   'carburetor',
#   'carburetor',
#   'car',
#   'guy',
#   'thing',
#   'way',
#   'females',
#   'wind',
#   'female',
#   'whole',
#   'dice',
#   'dice',
#   'next',
#   'dude',
#   'fucking',
#   'kitchen',
#   'simple',
#   'street',
#   'memory',
#   'street',
#   'shower',
#   'shower',
#   'shower',
#   'hot',
#   'world',
#   'hugging',
#   'tabernacle',
#   'deal',
#   'shit',
#   'stuff',
#   'way',
#   'rain',
#   'cafeteria',
#   'fuck',
#   'shit',
#   'adult',
#   'principal',
#   'fucking',
#   'kid',
#   'family',
#   'big',
#   'superintendent',
#   'mayoral',
#   'middle',
#   'deadline',
#   'bullying',
#   'superintendent',
#   'mayoral',
#   'conversation',
#   'youtube',
#   'raccoon',
#   'cats',
#   'cat',
#   'raccoon',
#   'next',
#   'kids',
#   'most',
#   'other',
#   'bottom',
#   'kid',
#   'instant',
#   'kid',
#   'factory',
#   'states',
#   'car',
#   'rest',
#   'hell',
#   'greatest',
#   'couch',
#   'kid',
#   'gate',
#   'second',
#   'offensive',
#   'blindside',
#   'world',
#   'dollar',
#   'problem',
#   'discipline',
#   'boy',
#   'sweatshop',
#   'answer',
#   'bed',
#   'bushes',
#   'fuck',
#   'fuckin',
#   'window',
#   'complete',
#   'city',
#   'dollar',
#   'outskirts',
#   'helicopter',
#   'helicopter',
#   'ultimate',
#   'situation',
#   'street',
#   'red',
#   'goddamn',
#   'living',
#   'shit',
#   'fan',
#   'fuck',
#   'fuck',
#   'street',
#   'place',
#   'same',
#   'business',
#   'american',
#   'family',
#   'family',
#   'dude',
#   'kid',
#   'money',
#   'tour',
#   'dude',
#   'balloons',
#   'cake',
#   'family',
#   'traditional',
#   'speech',
#   'helicopter',
#   'left',
#   'aircraft',
#   'door',
#   'fuck',
#   'fuck',
#   'fuck',
#   'fuck',
#   'fucking',
#   'story',
#   'guy',
#   'decision',
#   'land',
#   'chopper',
#   'dashboard',
#   'tour',
#   'door',
#   'thing',
#   'guy',
#   'ocean',
#   'air',
#   'most',
#   'history',
#   'way',
#   'hospital',
#   'balls',
#   'sly',
#   'holster',
#   'fucking',
#   'gun',
#   'briefcase',
#   'end',
#   'job',
#   'street',
#   'joke',
#   'south',
#   'its',
#   'gun',
#   'car',
#   'trigger',
#   'muzzle',
#   'gun',
#   'trigger',
#   'gun',
#   'sake',
#   'gun',
#   'bullets',
#   'thing',
#   'morning',
#   'psychos',
#   'morning',
#   'morning',
#   'sake',
#   'covers',
#   'morning',
#   'living',
#   'way',
#   'floorboards',
#   'floor',
#   'matter',
#   'matter',
#   'matter',
#   'matter',
#   'matter',
#   'matter',
#   'bed',
#   'fucking',
#   'you',
#   'fact',
#   'gun',
#   'trigger',
#   'fuck',
#   'toughest',
#   'very',
#   'end',
#   'douchebaggery',
#   'pilot',
#   'bowed',
#   'sugar',
#   'other',
#   'most',
#   'way',
#   'bed',
#   'covers',
#   'one',
#   'morning',
#   'other',
#   'couch',
#   'kitchen',
#   'couch',
#   'back',
#   'couch',
#   'couch',
#   'first',
#   'window',
#   'next',
#   'sex',
#   'most',
#   'fucking',
#   'last',
#   'kitchen',
#   'tv',
#   'shit',
#   'nerds',
#   'cheerleader',
#   'love',
#   'saxophone',
#   'penetration',
#   'other',
#   'shit',
#   'hell',
#   'first',
#   'cops',
#   'raciest',
#   'wall',
#   'other',
#   'wall',
#   'most',
#   'races',
#   'movie',
#   'guy',
#   'other',
#   'movie',
#   'bed',
#   'bed',
#   'way',
#   'gym',
#   'bed',
#   'wall',
#   'whole'],
#  'greater': ['atlanta'],
#  'atlanta': ['georgia', 'comedy', 'i', 'youre', 'might'],
#  'georgia': ['area'],
#  'area': ['this'],
#  'this': ['oasis',
#   'thing',
#   'cattle',
#   'planet',
#   'will',
#   'day',
#   'country',
#   'year',
#   'slaverythemed',
#   'summer',
#   'crazy',
#   'dude',
#   'guys',
#   'guy',
#   'fucking',
#   'like',
#   'you',
#   'monica',
#   'crazy',
#   'yk',
#   'shit',
#   'old',
#   'isnt',
#   'shits',
#   'redneck',
#   'scared',
#   'is',
#   'guy',
#   'spaceship',
#   'is',
#   'why',
#   'is',
#   'shit',
#   'pound',
#   'fucking',
#   'am',
#   'right',
#   'dude',
#   'weird',
#   'right',
#   'might',
#   'is',
#   'around',
#   'things',
#   'i',
#   'great',
#   'great',
#   'for',
#   'for',
#   'bus',
#   'turbulence',
#   'dude',
#   'fuselage',
#   'guy',
#   'bus',
#   'is',
#   'is',
#   'is',
#   'guy',
#   'dude',
#   'country',
#   'day',
#   'is',
#   'is',
#   'lady',
#   'i',
#   'tall',
#   'like',
#   'shirt',
#   'kid',
#   'sawedoff',
#   'shit',
#   'im',
#   'this',
#   'looks',
#   'and',
#   'story',
#   'guy',
#   'poor',
#   'guy',
#   'kid',
#   'frequency',
#   'guy',
#   'guy',
#   'guy',
#   'is',
#   'is',
#   'all',
#   'guys',
#   'fiveshot',
#   'point',
#   'was',
#   'is',
#   'shadowy',
#   'strobe',
#   'shit',
#   'house',
#   'the',
#   'its',
#   'is',
#   'is',
#   'onedimensional',
#   'little',
#   'shes',
#   'is',
#   'mattress'],
#  'oasis': ['its'],
#  'nice': ['to', 'to', 'you', 'especially', 'he', 'its', 'in'],
#  'i': ['dont',
#   'came',
#   'get',
#   'been',
#   'hate',
#   'decided',
#   'can',
#   'realized',
#   'saw',
#   'guess',
#   'have',
#   'would',
#   'didnt',
#   'look',
#   'think',
#   'want',
#   'was',
#   'got',
#   'dont',
#   'was',
#   'am',
#   'dont',
#   'dont',
#   'feel',
#   'mean',
#   'ever',
#   'didnt',
#   'dont',
#   'thought',
#   'j',
#   'swear',
#   'bet',
#   'think',
#   'feel',
#   'dont',
#   'cant',
#   'had',
#   'was',
#   'gotta',
#   'was',
#   'got',
#   'guess',
#   'have',
#   'dont',
#   'mean',
#   'dont',
#   'put',
#   'lasted',
#   'was',
#   'was',
#   'dont',
#   'understand',
#   'dont',
#   'might',
#   'might',
#   'have',
#   'nuts',
#   'know',
#   'know',
#   'dont',
#   'totally',
#   'was',
#   'would',
#   'never',
#   'tried',
#   'think',
#   'dont',
#   'dont',
#   'go',
#   'thought',
#   'was',
#   'dont',
#   'dont',
#   'always',
#   'learned',
#   'think',
#   'actually',
#   'had',
#   'didnt',
#   'didnt',
#   'just',
#   'dont',
#   'already',
#   'got',
#   'actually',
#   'had',
#   'felt',
#   'did',
#   'think',
#   'havent',
#   'have',
#   'think',
#   'could',
#   'see',
#   'live',
#   'heard',
#   'was',
#   'have',
#   'know',
#   'am',
#   'said',
#   'ever',
#   'was',
#   'can',
#   'think',
#   'heard',
#   'was',
#   'heard',
#   'was',
#   'heard',
#   'lost',
#   'got',
#   'your',
#   'was',
#   'just',
#   'gonna',
#   'gonna',
#   'gonna',
#   'kind',
#   'act',
#   'go',
#   'dont',
#   'did',
#   'just',
#   'didnt',
#   'just',
#   'just',
#   'havent',
#   'was',
#   'dont',
#   'say',
#   'actually',
#   'made',
#   'built',
#   'wouldnt',
#   'wouldnt',
#   'would',
#   'got',
#   'believe',
#   'was',
#   'supposed',
#   'didnt',
#   'dont',
#   'dont',
#   'knew',
#   'knew',
#   'was',
#   'couldnt',
#   'was',
#   'got',
#   'hate',
#   'get',
#   'have',
#   'never',
#   'dont',
#   'just',
#   'believe',
#   'just',
#   'dont',
#   'have',
#   'dont',
#   'just',
#   'had',
#   'am',
#   'noticed',
#   'dont',
#   'am',
#   'am',
#   'was',
#   'didnt',
#   'came',
#   'came',
#   'didnt',
#   'dont',
#   'didnt',
#   'think',
#   'was',
#   'moved',
#   'drive',
#   'think',
#   'have',
#   'dont',
#   'think',
#   'have',
#   'did',
#   'just',
#   'actually',
#   'finally',
#   'saw',
#   'finally',
#   'wanted',
#   'was',
#   'was',
#   'always',
#   'got',
#   'end',
#   'know',
#   'dont',
#   'figure',
#   'ever',
#   'said',
#   'wont',
#   'wouldnt',
#   'would',
#   'have',
#   'dont',
#   'want',
#   'want',
#   'last',
#   'got',
#   'did',
#   'hang',
#   'just',
#   'felt',
#   'felt',
#   'was',
#   'didnt',
#   'would',
#   'feel',
#   'got',
#   'dont',
#   'get',
#   'still',
#   'just',
#   'do',
#   'get',
#   'should',
#   'should',
#   'think',
#   'already',
#   'want',
#   'do',
#   'want',
#   'would',
#   'gotta',
#   'am',
#   'get',
#   'dont',
#   'can',
#   'got',
#   'got',
#   'got',
#   'feel',
#   'might',
#   'feel',
#   'could',
#   'said',
#   'got',
#   'just',
#   'could',
#   'figured',
#   'figure',
#   'dont',
#   'have',
#   'want',
#   'actually',
#   'do',
#   'live',
#   'dont',
#   'love',
#   'told',
#   'want',
#   'know',
#   'was',
#   'was',
#   'gonna',
#   'get',
#   'got',
#   'never',
#   'never',
#   'needed',
#   'bought',
#   'saw',
#   'built',
#   'love',
#   'need',
#   'gotta',
#   'dont',
#   'read',
#   'love',
#   'love',
#   'loved',
#   'cant',
#   'decide',
#   'left',
#   'think',
#   'still',
#   'just',
#   'hope',
#   'have',
#   'mentioned',
#   'came',
#   'wanted',
#   'do',
#   'gave',
#   'cant',
#   'want',
#   'say',
#   'wanted',
#   'wanted',
#   'dont',
#   'had',
#   'shot',
#   'was',
#   'got',
#   'get',
#   'thought',
#   'dont',
#   'go',
#   'bring',
#   'pull',
#   'saw',
#   'felt',
#   'never',
#   'pulled',
#   'just',
#   'shot',
#   'got',
#   'will',
#   'get',
#   'get',
#   'got',
#   'understand',
#   'understand',
#   'maintain',
#   'dont',
#   'could',
#   'dont',
#   'dont',
#   'started',
#   'caught',
#   'guess',
#   'dont',
#   'stand',
#   'let',
#   'couldnt',
#   'was',
#   'sleep',
#   'go',
#   'always',
#   'will',
#   'want',
#   'was',
#   'sleep',
#   'want',
#   'need',
#   'felt',
#   'dont',
#   'dont',
#   'understand',
#   'fucking',
#   'just',
#   'just',
#   'am',
#   'am',
#   'occasionally',
#   'dont',
#   'dont',
#   'just',
#   'want',
#   'want',
#   'dont',
#   'remember',
#   'didnt',
#   'was',
#   'was',
#   'didnt',
#   'thought',
#   'was',
#   'dont',
#   'just',
#   'want',
#   'dont',
#   'want',
#   'swear',
#   'guess',
#   'didnt',
#   'love',
#   'saw',
#   'ruined',
#   'cant',
#   'can',
#   'had'],
#  'dont': ['know',
#   'know',
#   'like',
#   'understand',
#   'see',
#   'hit',
#   'know',
#   'know',
#   'promote',
#   'promote',
#   'give',
#   'have',
#   'be',
#   'touch',
#   'know',
#   'even',
#   'want',
#   'know',
#   'fucking',
#   'give',
#   'get',
#   'clap',
#   'clap',
#   'read',
#   'read',
#   'understand',
#   'understand',
#   'they',
#   'care',
#   'like',
#   'kill',
#   'touch',
#   'have',
#   'go',
#   'know',
#   'think',
#   'give',
#   'give',
#   'like',
#   'like',
#   'believe',
#   'think',
#   'get',
#   'work',
#   'even',
#   'know',
#   'know',
#   'know',
#   'know',
#   'have',
#   'change',
#   'hug',
#   'want',
#   'understand',
#   'understand',
#   'understand',
#   'understand',
#   'know',
#   'even',
#   'even',
#   'even',
#   'even',
#   'know',
#   'know',
#   'live',
#   'open',
#   'dont',
#   'stop',
#   'know',
#   'try',
#   'dont',
#   'dont',
#   'incredible',
#   'know',
#   'understand',
#   'be',
#   'come',
#   'care',
#   'give',
#   'care',
#   'even',
#   'tell',
#   'tell',
#   'i',
#   'understand',
#   'care',
#   'mind',
#   'like',
#   'even',
#   'know',
#   'you',
#   'i',
#   'think',
#   'put',
#   'walk'],
#  'know': ['why',
#   'i',
#   'that',
#   'i',
#   'if',
#   'michael',
#   'anybody',
#   'its',
#   'would',
#   'its',
#   'just',
#   'you',
#   'you',
#   'i',
#   'i',
#   'how',
#   'theyre',
#   'what',
#   'a',
#   'what',
#   'just',
#   'his',
#   'cause',
#   'what',
#   'so',
#   'so',
#   'when',
#   'i',
#   'im',
#   'but',
#   'what',
#   'you',
#   'what',
#   'i',
#   'dont',
#   'i',
#   'were',
#   'i',
#   'the',
#   'like',
#   'what',
#   'they',
#   'we',
#   'theres',
#   'what',
#   'just',
#   'that',
#   'id',
#   'about',
#   'jesus',
#   'you',
#   'what',
#   'you',
#   'you',
#   'what',
#   'what',
#   'he',
#   'when',
#   'man',
#   'in',
#   'thats',
#   'that',
#   'about',
#   'what',
#   'how',
#   'i',
#   'hes',
#   'they',
#   'they',
#   'come',
#   'those',
#   'right',
#   'think',
#   'its',
#   'what',
#   'what',
#   'the',
#   'yeah',
#   'the',
#   'why',
#   'why',
#   'if',
#   'what',
#   'why',
#   'maybe',
#   'that',
#   'or',
#   'whos',
#   'what',
#   'i',
#   'im',
#   'whats',
#   'how',
#   'if',
#   'what',
#   'what',
#   'i',
#   'its',
#   'that'],
#  'why': ['i',
#   'a',
#   'do',
#   'dont',
#   'i',
#   'does',
#   'does',
#   'wouldnt',
#   'did',
#   'that',
#   'i',
#   'are',
#   'it',
#   'cause',
#   'it',
#   'i',
#   'dont',
#   'dont'],
#  'came': ['here',
#   'in',
#   'back',
#   'walking',
#   'down',
#   'out',
#   'to',
#   'through',
#   'in',
#   'from',
#   'through'],
#  'june': ['its'],
#  'wasnt': ['thinking', 'offensive', 'that', 'alive'],
#  'thinking': ['fucking',
#   'about',
#   'of',
#   'whaaa',
#   'its',
#   'of',
#   'about',
#   'he',
#   'three'],
#  'fucking': ['ridiculously',
#   'loser',
#   'loser',
#   'sitting',
#   'got',
#   'stupidass',
#   'joke',
#   'joel',
#   'electric',
#   'old',
#   'liberal',
#   'guy',
#   'going',
#   'understand',
#   'world',
#   'moron',
#   'update',
#   'ideas',
#   'horrific',
#   'story',
#   'that',
#   'nuts',
#   'ever',
#   'sense',
#   'scared',
#   'kids',
#   'stupid',
#   'lunch',
#   'axe',
#   'door',
#   'knock',
#   'horrific',
#   'cheetoeating',
#   'do',
#   'eightyearold',
#   'late',
#   'kills',
#   'time',
#   'killed',
#   'bring',
#   'sitting',
#   'daycare',
#   'jumped',
#   'days',
#   'helicopter',
#   'cape',
#   'foot',
#   'lived',
#   'battles',
#   'have',
#   'bums',
#   'minds',
#   'guys',
#   'thing',
#   'glasses',
#   'earplugs',
#   'lawn',
#   'guns',
#   'loaded',
#   'sickle',
#   'lying',
#   'around',
#   'miss',
#   'bed',
#   'sleep',
#   'chokeslam',
#   'hate',
#   'bread',
#   'nice',
#   'bullshit'],
#  'ridiculously': ['hot'],
#  'hot': ['out', 'water'],
#  'out': ['there',
#   'and',
#   'and',
#   'there',
#   'you',
#   'there',
#   'it',
#   'its',
#   'there',
#   'with',
#   'to',
#   'of',
#   'your',
#   'with',
#   'in',
#   'of',
#   'what',
#   'what',
#   'there',
#   'of',
#   'of',
#   'and',
#   'in',
#   'there',
#   'bottomless',
#   'of',
#   'yes',
#   'afterwards',
#   'of',
#   'of',
#   'the',
#   'like',
#   'here',
#   'of',
#   'that',
#   'of',
#   'of',
#   'in',
#   'for',
#   'in',
#   'of',
#   'and',
#   'with',
#   'he',
#   'today',
#   'of',
#   'there',
#   'of',
#   'of',
#   'of',
#   'in',
#   'all',
#   'fucking',
#   'the',
#   'here',
#   'vehicle',
#   'and',
#   'and',
#   'and',
#   'there',
#   'yeah',
#   'the',
#   'of',
#   'the',
#   'he',
#   'what',
#   'like',
#   'like',
#   'like',
#   'gets',
#   'one',
#   'over',
#   'of',
#   'of',
#   'cause',
#   'of',
#   'of',
#   'of',
#   'at',
#   'with',
#   'of',
#   'your',
#   'of',
#   'the',
#   'we',
#   'of',
#   'no',
#   'and',
#   'there',
#   'or',
#   'you',
#   'the',
#   'neutralized',
#   'in',
#   'theyre',
#   'of',
#   'of',
#   'my',
#   'of'],
#  'there': ['just',
#   'drinkin',
#   'and',
#   'bitch',
#   'watching',
#   'theyre',
#   'and',
#   'is',
#   'telling',
#   'that',
#   'with',
#   'i',
#   'and',
#   'was',
#   'was',
#   'was',
#   'be',
#   'is',
#   'theyre',
#   'over',
#   'gas',
#   'jstar',
#   'sleeping',
#   'right',
#   'used',
#   'mwah',
#   'ill',
#   'next',
#   'you',
#   'going',
#   'mom',
#   'like',
#   'fighting',
#   'and',
#   'looking',
#   'he',
#   'he',
#   'hovering',
#   'in',
#   'eating',
#   'goes',
#   'were',
#   'were',
#   'until',
#   'flying',
#   'put',
#   'is',
#   'well',
#   'right',
#   'never',
#   'dont',
#   'you',
#   'loaded',
#   'same',
#   'all',
#   'like',
#   'that',
#   'is',
#   'i',
#   'is',
#   'use'],
#  'just': ['miserable',
#   'over',
#   'in',
#   'had',
#   'wont',
#   'say',
#   'sits',
#   'fucking',
#   'to',
#   'like',
#   'be',
#   'dont',
#   'dont',
#   'walking',
#   'keep',
#   'stuck',
#   'keeps',
#   'coming',
#   'be',
#   'in',
#   'fuckin',
#   'brainwash',
#   'this',
#   'didnt',
#   'sort',
#   'about',
#   'start',
#   'the',
#   'hit',
#   'like',
#   'floating',
#   'had',
#   'yeah',
#   'just',
#   'let',
#   'let',
#   'let',
#   'sliding',
#   'let',
#   'sliding',
#   'goes',
#   'keeps',
#   'stops',
#   'let',
#   'let',
#   'floated',
#   'just',
#   'layin',
#   'dead',
#   'light',
#   'sitting',
#   'settles',
#   'keep',
#   'dead',
#   'like',
#   'dont',
#   'dont',
#   'wish',
#   'be',
#   'as',
#   'tried',
#   'so',
#   'be',
#   'be',
#   'think',
#   'made',
#   'be',
#   'being',
#   'like',
#   'be',
#   'accidentally',
#   'must',
#   'leave',
#   'weird',
#   'couldnt',
#   'sitting',
#   'its',
#   'be',
#   'came',
#   'thinking',
#   'turned',
#   'turned',
#   'feel',
#   'gonna',
#   'to',
#   'turned',
#   'turned',
#   'show',
#   'there',
#   'show',
#   'bring',
#   'thought',
#   'talking',
#   'doing',
#   'look',
#   'look',
#   'land',
#   'sit',
#   'like',
#   'that',
#   'gonna',
#   'not',
#   'gonna',
#   'gonna',
#   'gonna',
#   'like',
#   'sitting',
#   'jumped',
#   'taking',
#   'but',
#   'feel',
#   'get',
#   'yeah',
#   'sit',
#   'heard',
#   'kept',
#   'say',
#   'say',
#   'meanwhile',
#   'listening',
#   'hears',
#   'fucking',
#   'like',
#   'see',
#   'wont',
#   'standing',
#   'no',
#   'got',
#   'sleep',
#   'sleep',
#   'sleep',
#   'gonna',
#   'grab',
#   'sit',
#   'start',
#   'saying',
#   'want',
#   'keep',
#   'everythings',
#   'yeah',
#   'do',
#   'dont',
#   'so',
#   'so',
#   'kept',
#   'like',
#   'kinda',
#   'got',
#   'lay'],
#  'miserable': ['horrible', 'eightday'],
#  'horrible': ['that'],
#  'that': ['kind',
#   'something',
#   'shit',
#   'shit',
#   'is',
#   'as',
#   'you',
#   'its',
#   'what',
#   'shit',
#   'fucks',
#   'yeah',
#   'you',
#   'joke',
#   'yeah',
#   'joke',
#   'joke',
#   'get',
#   'fucked',
#   'fucking',
#   'guy',
#   'guy',
#   'got',
#   'older',
#   'makes',
#   'dude',
#   'shit',
#   'shit',
#   'clippers',
#   'wasnt',
#   'bad',
#   'whole',
#   'tape',
#   'he',
#   'finished',
#   'savage',
#   'youre',
#   'you',
#   'is',
#   'old',
#   'was',
#   'was',
#   'you',
#   'you',
#   'doesnt',
#   'mma',
#   'shit',
#   'is',
#   'im',
#   'duck',
#   'homophobic',
#   'he',
#   'fuckin',
#   'homophobic',
#   'all',
#   'shit',
#   'duck',
#   'he',
#   'shit',
#   'same',
#   'thats',
#   'call',
#   'religious',
#   'all',
#   'i',
#   'sock',
#   'is',
#   'is',
#   'a',
#   'walked',
#   'made',
#   'make',
#   'shit',
#   'sound',
#   'made',
#   'stuff',
#   'person',
#   'douche',
#   'creepy',
#   'moment',
#   'rock',
#   'rock',
#   'im',
#   'somebodys',
#   'doesnt',
#   'they',
#   'there',
#   'i',
#   'and',
#   'im',
#   'make',
#   'is',
#   'dude',
#   'little',
#   'shit',
#   'knows',
#   'nobody',
#   'noise',
#   'help',
#   'carburetor',
#   'was',
#   'one',
#   'one',
#   'youre',
#   'that',
#   'fucking',
#   'guy',
#   'shit',
#   'you',
#   'hug',
#   'youre',
#   'but',
#   'shit',
#   'was',
#   'hug',
#   'you',
#   'stuff',
#   'was',
#   'my',
#   'your',
#   'worked',
#   'didnt',
#   'was',
#   'was',
#   'was',
#   'he',
#   'was',
#   'and',
#   'i',
#   'shit',
#   'at',
#   'i',
#   'did',
#   'one',
#   'again',
#   'im',
#   'they',
#   'i',
#   'works',
#   'be',
#   'made',
#   'kid',
#   'in',
#   'hell',
#   'right',
#   'shit',
#   'shit',
#   'every',
#   'you',
#   'no',
#   'shit',
#   'shit',
#   'full',
#   'way',
#   'city',
#   'see',
#   'water',
#   'came',
#   'she',
#   'shit',
#   'but',
#   'hey',
#   'what',
#   'for',
#   'mean',
#   'shut',
#   'old',
#   'point',
#   'guy',
#   'nana',
#   'guy',
#   'helicopter',
#   'would',
#   'sounds',
#   'didnt',
#   'i',
#   'dream',
#   'person',
#   'sir',
#   'little',
#   'the',
#   'what',
#   'or',
#   'thing',
#   'intruder',
#   'so',
#   'thing',
#   'has',
#   'hall',
#   'little',
#   'door',
#   'gun',
#   'fucker',
#   'its',
#   'a',
#   'if',
#   'okay',
#   'is',
#   'might',
#   'henpecked',
#   'dude',
#   'good',
#   'theres',
#   'will',
#   'shit',
#   'is',
#   'situation',
#   'ufc',
#   'threat',
#   'walk',
#   'i',
#   'about',
#   'enough',
#   'stupid',
#   'shit',
#   'taboo',
#   'whole',
#   'whole',
#   'is',
#   'a',
#   'and',
#   'and',
#   'was',
#   'is',
#   'dude',
#   'other'],
#  'kind': ['of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of'],
#  'of': ['heat',
#   'those',
#   'you',
#   'you',
#   'a',
#   'a',
#   'a',
#   'the',
#   'power',
#   'children',
#   'chalkboard',
#   'that',
#   'humor',
#   'it',
#   'a',
#   'that',
#   'signs',
#   'those',
#   'shit',
#   'these',
#   'old',
#   'her',
#   'themes',
#   'the',
#   'these',
#   'a',
#   'instagram',
#   'this',
#   'the',
#   'the',
#   'here',
#   'the',
#   'mice',
#   'kids',
#   'the',
#   'the',
#   'this',
#   'this',
#   'them',
#   'a',
#   'my',
#   'the',
#   'a',
#   'that',
#   'nowhere',
#   'pages',
#   'pedophilia',
#   'it',
#   'mulching',
#   'every',
#   'every',
#   'which',
#   'how',
#   'scientologists',
#   'scientology',
#   'years',
#   'it',
#   'him',
#   'it',
#   'believing',
#   'shit',
#   'shrimp',
#   'course',
#   'that',
#   'your',
#   'this',
#   'go',
#   'times',
#   'the',
#   'it',
#   'them',
#   'a',
#   'nowhere',
#   'it',
#   'it',
#   'the',
#   'your',
#   'choice',
#   'shit',
#   'your',
#   'your',
#   'brussels',
#   'hard',
#   'that',
#   'entitlement',
#   'flying',
#   'it',
#   'a',
#   'that',
#   'people',
#   'a',
#   'nowhere',
#   'a',
#   'like',
#   'a',
#   'a',
#   'whoo',
#   'the',
#   'your',
#   'that',
#   'them',
#   'that',
#   'my',
#   'your',
#   'shit',
#   'myself',
#   'the',
#   'that',
#   'those',
#   'those',
#   'then',
#   'him',
#   'tomfoolery',
#   'the',
#   'the',
#   'a',
#   'natural',
#   'my',
#   'those',
#   'cold',
#   'lets',
#   'doing',
#   'my',
#   'you',
#   'fritos',
#   'those',
#   'the',
#   'that',
#   'whats',
#   'his',
#   'a',
#   'this',
#   'line',
#   'pop',
#   'planning',
#   'love',
#   'annoyed',
#   'a',
#   'the',
#   'beaches',
#   'beaches',
#   'the',
#   'pills',
#   'his',
#   'beaches',
#   'the',
#   'an',
#   'jumping',
#   'a',
#   'pain',
#   'your',
#   'your',
#   'the',
#   'the',
#   'shots',
#   'your',
#   'argument',
#   'these',
#   'my',
#   'argument',
#   'a',
#   'a',
#   'five',
#   'your',
#   'the',
#   'your',
#   'the',
#   'those',
#   'couple',
#   'what',
#   'the',
#   'her',
#   'the',
#   'come',
#   'sports',
#   'her',
#   'that',
#   'that',
#   'a',
#   'scare',
#   'me',
#   'rape',
#   'like',
#   'upagainstthewall',
#   'nowhere',
#   'the',
#   'damage',
#   'me',
#   'its',
#   'time'],
#  'heat': ['you'],
#  'understand': ['the',
#   'like',
#   'the',
#   'that',
#   'you',
#   'i',
#   'why',
#   'anything',
#   'you',
#   'cold',
#   'being',
#   'sevenyearold',
#   'that',
#   'what',
#   'that',
#   'that',
#   'how',
#   'if',
#   'it'],
#  'racism': ['down', 'i'],
#  'down': ['here',
#   'hes',
#   'this',
#   'to',
#   'the',
#   'up',
#   'none',
#   'push',
#   'deny',
#   'to',
#   'here',
#   'right',
#   'the',
#   'the',
#   'to',
#   'to',
#   'to',
#   'into',
#   'to',
#   'the',
#   'i',
#   'yeah',
#   'on',
#   'on',
#   'to',
#   'the',
#   'in',
#   'in',
#   'just',
#   'hes',
#   'south',
#   'to',
#   'the',
#   'to',
#   'there',
#   'that',
#   'the',
#   'from',
#   'like',
#   'but',
#   'choke',
#   'try',
#   'they',
#   'on',
#   'the'],
#  'ya': ['know', 'know', 'know', 'know', 'know', 'know'],
#  'get': ['it',
#   'along',
#   'in',
#   'its',
#   'for',
#   'too',
#   'in',
#   'back',
#   'it',
#   'that',
#   'out',
#   'married',
#   'them',
#   'the',
#   'in',
#   'old',
#   'in',
#   'the',
#   'on',
#   'a',
#   'judged',
#   'judged',
#   'a',
#   'my',
#   'older',
#   'any',
#   'the',
#   'yourself',
#   'up',
#   'there',
#   'rid',
#   'out',
#   'the',
#   'weird',
#   'some',
#   'chocolate',
#   'it',
#   'to',
#   'i',
#   'like',
#   'in',
#   'to',
#   'him',
#   'like',
#   'in',
#   'to',
#   'to',
#   'my',
#   'in',
#   'a',
#   'one',
#   'a',
#   'down',
#   'louder',
#   'quieter',
#   'crazy',
#   'off',
#   'it',
#   'it',
#   'along',
#   'me',
#   'yourself',
#   'you',
#   'me',
#   'nearly',
#   'off'],
#  'it': ['how',
#   'till',
#   'nobody',
#   'that',
#   'i',
#   'up',
#   'they',
#   'we',
#   'feel',
#   'yeah',
#   'doesnt',
#   'they',
#   'down',
#   'puts',
#   'on',
#   'what',
#   'did',
#   'was',
#   'was',
#   'was',
#   'yeah',
#   'went',
#   'once',
#   'other',
#   'on',
#   'was',
#   'other',
#   'on',
#   'off',
#   'was',
#   'happens',
#   'thats',
#   'passes',
#   'passing',
#   'on',
#   'went',
#   'if',
#   'id',
#   'come',
#   'they',
#   'a',
#   'like',
#   'say',
#   'again',
#   'ill',
#   'again',
#   'right',
#   'stands',
#   'was',
#   'right',
#   'i',
#   'like',
#   'in',
#   'ill',
#   'just',
#   'is',
#   'be',
#   'like',
#   'i',
#   'and',
#   'dead',
#   'didnt',
#   'forever',
#   'on',
#   'but',
#   'to',
#   'just',
#   'and',
#   'going',
#   'going',
#   'the',
#   'he',
#   'its',
#   'has',
#   'stops',
#   'comes',
#   'down',
#   'down',
#   'used',
#   'anymore',
#   'okay',
#   'then',
#   'your',
#   'theyre',
#   'didnt',
#   'and',
#   'was',
#   'was',
#   'is',
#   'on',
#   'was',
#   'was',
#   'was',
#   'was',
#   'go',
#   'out',
#   'from',
#   'down',
#   'down',
#   'isnt',
#   'one',
#   'made',
#   'to',
#   'was',
#   'was',
#   'up',
#   'you',
#   'im',
#   'though',
#   'in',
#   'in',
#   'again',
#   'down',
#   'is',
#   'doesnt',
#   'maybe',
#   'is',
#   'you',
#   'still',
#   'im',
#   'pass',
#   'by',
#   'im',
#   'all',
#   'up',
#   'was',
#   'yeah',
#   'looked',
#   'has',
#   'cant',
#   'fucking',
#   'between',
#   'down',
#   'out',
#   'back',
#   'at',
#   'fuck',
#   'so',
#   'at',
#   'didnt',
#   'there',
#   'works',
#   'i',
#   'that',
#   'okay',
#   'go',
#   'out',
#   'its',
#   'was',
#   'been',
#   'right',
#   'right',
#   'always',
#   'they',
#   'i',
#   'right',
#   'why',
#   'itll',
#   'i',
#   'was',
#   'was',
#   'nice',
#   'yeah',
#   'standing',
#   'with',
#   'he',
#   'in',
#   'up',
#   'you'],
#  'would': ['you',
#   'be',
#   'implement',
#   'never',
#   'never',
#   'have',
#   'have',
#   'troubleshoot',
#   'you',
#   'fuck',
#   'send',
#   'come',
#   'love',
#   'love',
#   'that',
#   'love',
#   'be',
#   'be',
#   'leave',
#   'leave'],
#  'along': ['with', 'for', 'with'],
#  'with': ['anybody',
#   'my',
#   'that',
#   'birthday',
#   'your',
#   'you',
#   'them',
#   'them',
#   'them',
#   'em',
#   'em',
#   'your',
#   'your',
#   'these',
#   'this',
#   'your',
#   'his',
#   'a',
#   'your',
#   'myself',
#   'myself',
#   'this',
#   'like',
#   'that',
#   'my',
#   'your',
#   'the',
#   'a',
#   'this',
#   'a',
#   'those',
#   'his',
#   'the',
#   'people',
#   'the',
#   'the',
#   'a',
#   'the',
#   'an',
#   'all',
#   'me',
#   'that',
#   'you',
#   'the',
#   'the',
#   'him',
#   'your',
#   'your',
#   'your',
#   'a',
#   'this',
#   'a',
#   'a',
#   'my',
#   'the',
#   'the',
#   'my',
#   'little',
#   'her',
#   'your',
#   'every'],
#  'anybody': ['look',
#   'says',
#   'whos',
#   'address',
#   'dont',
#   'yet',
#   'i',
#   'else',
#   'see'],
#  'look': ['at',
#   'of',
#   'at',
#   'if',
#   'at',
#   'at',
#   'at',
#   'im',
#   'im',
#   'at',
#   'out',
#   'at',
#   'out',
#   'at',
#   'im'],
#  'at': ['em',
#   'least',
#   'people',
#   'the',
#   'no',
#   'walt',
#   'him',
#   'in',
#   'the',
#   'dennys',
#   'math',
#   'it',
#   'he',
#   'the',
#   'a',
#   'the',
#   'you',
#   'the',
#   'them',
#   'that',
#   'the',
#   'the',
#   'that',
#   'your',
#   'the',
#   'this',
#   'me',
#   'a',
#   'the',
#   'at',
#   'night',
#   'him',
#   'you',
#   'the',
#   'me',
#   'you',
#   'you'],
#  'em': ['just', 'like', 'you', 'man', 'down', 'off'],
#  'over': ['there',
#   'here',
#   'right',
#   'the',
#   'the',
#   'there',
#   'blew',
#   'hey',
#   'you',
#   'with',
#   'here',
#   'here',
#   'your',
#   'no',
#   'cause',
#   'so',
#   'i',
#   'the',
#   'the',
#   'miles',
#   'miles',
#   'the',
#   'here',
#   'here',
#   'here',
#   'television',
#   'here'],
#  'drinkin': ['a'],
#  'cold': ['drink', 'out', 'till', 'teeth'],
#  'drink': ['lemonade', 'that'],
#  'lemonade': ['was'],
#  'was': ['made',
#   'doing',
#   'up',
#   'weird',
#   'like',
#   'offensive',
#   'at',
#   'the',
#   'wide',
#   'born',
#   'fine',
#   'gonna',
#   'he',
#   'a',
#   'considered',
#   'like',
#   'when',
#   'born',
#   'openminded',
#   'a',
#   'music',
#   'music',
#   'wrong',
#   'in',
#   'gonna',
#   'a',
#   'im',
#   'i',
#   'you',
#   'like',
#   'alive',
#   'working',
#   'like',
#   'an',
#   'four',
#   'still',
#   'a',
#   'the',
#   'as',
#   'just',
#   'just',
#   'basically',
#   'doing',
#   'you',
#   'brought',
#   'gonna',
#   'like',
#   'like',
#   'basically',
#   'standing',
#   'it',
#   'over',
#   'over',
#   'just',
#   'except',
#   'this',
#   'hugged',
#   'your',
#   'like',
#   'little',
#   'it',
#   'like',
#   'horrific',
#   'like',
#   'afraid',
#   'gonna',
#   'like',
#   'your',
#   'protecting',
#   'afraid',
#   'gonna',
#   'a',
#   'my',
#   'that',
#   'his',
#   'his',
#   'starting',
#   'just',
#   'eight',
#   'scratching',
#   'just',
#   'gonna',
#   'weird',
#   'established',
#   'years',
#   'in',
#   'wrong',
#   'falling',
#   'trying',
#   'i',
#   'just',
#   'landscaping',
#   'gonna',
#   'i',
#   'like',
#   'just',
#   'like',
#   'one',
#   'doing',
#   'just',
#   'like',
#   'doing',
#   'testing',
#   'just',
#   'her',
#   'her',
#   'lift',
#   'it',
#   'off'],
#  'made': ['for',
#   'sense',
#   'total',
#   'sense',
#   'me',
#   'a',
#   'of',
#   'an',
#   'of',
#   'this',
#   'fuck'],
#  'for': ['the',
#   'me',
#   'me',
#   'the',
#   'three',
#   'some',
#   'watching',
#   'you',
#   'jesus',
#   'jesus',
#   'an',
#   'an',
#   'a',
#   'someone',
#   'all',
#   'the',
#   'the',
#   'my',
#   'fucking',
#   'a',
#   'a',
#   'me',
#   'you',
#   'me',
#   'himself',
#   'that',
#   'you',
#   'a',
#   'me',
#   'what',
#   'years',
#   'years',
#   'him',
#   'home',
#   'the',
#   'gods',
#   'the',
#   'bear',
#   'youre',
#   'my',
#   'longer'],
#  'white': ['man', 'guy', 'guy', 'baseball', 'players', 'and', 'silk'],
#  'man': ['so',
#   'but',
#   'im',
#   'you',
#   'ah',
#   'shoulders',
#   'doesnt',
#   'getting',
#   'to',
#   'push',
#   'shit',
#   'shit',
#   'thats',
#   'and',
#   'like',
#   'im',
#   'its',
#   'i',
#   'take',
#   'quit'],
#  'so': ['what',
#   'i',
#   'yeah',
#   'whatever',
#   'what',
#   'focused',
#   'full',
#   'i',
#   'im',
#   'i',
#   'i',
#   'well',
#   'you',
#   'yeah',
#   'it',
#   'dumb',
#   'now',
#   'ive',
#   'this',
#   'yeah',
#   'they',
#   'youre',
#   'goddamn',
#   'one',
#   'im',
#   'fucking',
#   'fucking',
#   'before',
#   'we',
#   'awful',
#   'yeah',
#   'in',
#   'she',
#   'yeah',
#   'that',
#   'i',
#   'he',
#   'lady',
#   'you',
#   'yeah',
#   'now',
#   'the',
#   'what',
#   'thats',
#   'thats',
#   'i',
#   'god',
#   'i',
#   'there',
#   'he',
#   'i',
#   'im',
#   'that',
#   'heres',
#   'where',
#   'yeah',
#   'goddamn',
#   'what',
#   'im',
#   'i',
#   'lets',
#   'stretch',
#   'lets',
#   'mad',
#   'theres',
#   'thats',
#   'now',
#   'fucking',
#   'psyched',
#   'much'],
#  'what': ['the',
#   'i',
#   'about',
#   'do',
#   'im',
#   'kind',
#   'you',
#   'kind',
#   'were',
#   'do',
#   'are',
#   'do',
#   'these',
#   'pissed',
#   'did',
#   'the',
#   'did',
#   'about',
#   'a',
#   'a',
#   'a',
#   'did',
#   'his',
#   'happened',
#   'these',
#   'these',
#   'he',
#   'did',
#   'you',
#   'kills',
#   'we',
#   'they',
#   'happened',
#   'happens',
#   'happened',
#   'they',
#   'it',
#   'happened',
#   'am',
#   'am',
#   'i',
#   'their',
#   'they',
#   'im',
#   'do',
#   'are',
#   'i',
#   'hes',
#   'kills',
#   'absolutely',
#   'we',
#   'do',
#   'the',
#   'i',
#   'it',
#   'it',
#   'happens',
#   'do',
#   'is',
#   'is',
#   'im',
#   'you',
#   'i',
#   'i',
#   'i',
#   'other',
#   'is',
#   'is',
#   'does',
#   'is',
#   'are',
#   'the',
#   'the',
#   'the',
#   'the',
#   'was',
#   'i',
#   'he',
#   'i',
#   'do',
#   'you',
#   'happened',
#   'the',
#   'are',
#   'are',
#   'are',
#   'kills',
#   'are',
#   'is',
#   'is',
#   'can',
#   'you',
#   'she',
#   'she',
#   'are',
#   'does',
#   'shes',
#   'and'],
#  'hell': ['have',
#   'they',
#   'she',
#   'you',
#   'are',
#   'hes',
#   'be',
#   'be',
#   'give',
#   'of',
#   'that',
#   'support',
#   'with'],
#  'have': ['i',
#   'to',
#   'been',
#   'the',
#   'the',
#   'everybody',
#   'fuckin',
#   'some',
#   'a',
#   'all',
#   'the',
#   'some',
#   'those',
#   'an',
#   'a',
#   'been',
#   'sex',
#   'noticed',
#   'sex',
#   'a',
#   'time',
#   'three',
#   'kids',
#   'like',
#   'your',
#   'no',
#   'that',
#   'put',
#   'sometimes',
#   'ever',
#   'eggs',
#   'me',
#   'ate',
#   'a',
#   'never',
#   'answers',
#   'this',
#   'empathy',
#   'to',
#   'to',
#   'time',
#   'a',
#   'any',
#   'a',
#   'been',
#   'a',
#   'to',
#   'to',
#   'a',
#   'a',
#   'kids',
#   'kids',
#   'a',
#   'a',
#   'to',
#   'a',
#   'to',
#   'to',
#   'yelled',
#   'no',
#   'been',
#   'been',
#   'gone',
#   'the',
#   'some',
#   'you',
#   'you',
#   'time',
#   'time',
# ...
#   'man',
#   'come',
#   'what',
#   'i',
#   'where',
#   'hows',
#   'hey',
#   'hey',
#   'hey',
#   'hey',
#   'rest'],
#  'give': ['a',
#   'a',
#   'him',
#   'me',
#   'a',
#   'a',
#   'you',
#   'a',
#   'him',
#   'him',
#   'him',
#   'a',
#   'him',
#   'a'],
#  'years': ['old',
#   'before',
#   'of',
#   'up',
#   'to',
#   'old',
#   'later',
#   'ago',
#   'ago',
#   'old',
#   'they',
#   'old',
#   'old',
#   'old',
#   'years',
#   'without',
#   'here',
#   'old'],
#  'math': ['this', 'and'],
#  'born': ['in', 'i', 'do'],
#  'before': ['jackie', 'when', 'before', 'there', 'you', 'i', 'rem', 'theyre'],
#  'jackie': ['robinson'],
#  'robinson': ['broke'],
#  'broke': ['the'],
#  'color': ['barrier', 'yeah'],
#  'barrier': ['first'],
#  'first': ['and', 'and', 'time', 'time', 'draft', 'fear', 'time'],
#  'half': ['years', 'years', 'whooo', 'naked', 'a'],
#  'watched': ['allwhite', 'the'],
#  'allwhite': ['baseball'],
#  'baseball': ['and', 'white'],
#  'fine': ['first', 'youre', 'you'],
#  'whitey': ['willoughby'],
#  'willoughby': ['theres'],
#  'shot': ['out', 'at', 'the', 'that', 'a', 'a', 'the'],
#  'peter': ['peckerwood'],
#  'peckerwood': ['what'],
#  'catch': ['unbelievable'],
#  'chris': ['cracker'],
#  'cracker': ['what'],
#  'ballgame': ['white'],
#  'players': ['dude'],
#  'parents': ['were', 'come', 'did'],
#  'generation': ['that'],
#  'finished': ['off'],
#  'genocide': ['of'],
#  'native': ['americans'],
#  'americans': ['all'],
#  'taught': ['him'],
#  'abcs': ['you'],
#  'b': ['c'],
#  'c': ['d'],
#  'd': ['e'],
#  'e': ['hey'],
#  'savage': ['off'],
#  'property': ['get'],
#  'killed': ['all', 'anybody', 'people', 'sitting'],
#  'fence': ['around'],
#  'h': ['i'],
#  'j': ['k'],
#  'k': ['yeah'],
#  'big': ['crime', 'boy', 'dumb', 'planes', 'thing', 'brother', 'gun'],
#  'crime': ['was'],
#  'lived': ['too', 'yeah'],
#  'long': ['he', 'you', 'im', 'time'],
#  'hed': ['died', 'chill'],
#  'died': ['around', 'in', 'and', 'at'],
#  'noticed': ['dude', 'everything'],
#  'walt': ['disney', 'disney'],
#  'disney': ['walt', 'was'],
#  'known': ['antisemite'],
#  'antisemite': ['but'],
#  'early': ['s', 'on'],
#  's': ['nobody', 'he'],
#  'castle': ['bunch'],
#  'mice': ['running'],
#  'running': ['around'],
#  'cares': ['this'],
#  'kept': ['living', 'seeing', 'taking', 'putting'],
#  'living': ['telling', 'and', 'basically', 'room', 'room'],
#  'wear': ['out'],
#  'welcome': ['i'],
#  'swear': ['to', 'to', 'to'],
#  'bet': ['in'],
#  'considered': ['a'],
#  'hippie': ['you'],
#  'dads': ['getting', 'gonna', 'sleeping'],
#  'stay': ['with', 'with', 'away', 'away'],
#  'true': ['though', 'right', 'that'],
#  'pass': ['you', 'the'],
#  'by': ['it',
#   'i',
#   'im',
#   'ill',
#   'thursday',
#   'his',
#   'a',
#   'at',
#   'the',
#   'your',
#   'the'],
#  'happens': ['you', 'after', 'when', 'where'],
#  'basically': ['i', 'just', 'like', 'never', 'what', 'a', 'have', 'we'],
#  'absorb': ['as'],
#  'then': ['thats',
#   'you',
#   'you',
#   'you',
#   'one',
#   'what',
#   'one',
#   'go',
#   'you',
#   'maybe',
#   'he',
#   'he',
#   'i',
#   'you',
#   'he',
#   'theres',
#   'i',
#   'all',
#   'i',
#   'it',
#   'im',
#   'you',
#   'im',
#   'im',
#   'you',
#   'when',
#   'out',
#   'they',
#   'she'],
#  'married': ['and', 'thats', 'they', 'so'],
#  'couple': ['of', 'of', 'of', 'of', 'only', 'of', 'nights'],
#  'kids': ['youre',
#   'its',
#   'that',
#   'but',
#   'are',
#   'and',
#   'when',
#   'as',
#   'i',
#   'i',
#   'in',
#   'standing',
#   'most',
#   'are',
#   'when'],
#  'sucked': ['in'],
#  'bubble': ['you', 'you'],
#  'time': ['to',
#   'ago',
#   'i',
#   'and',
#   'im',
#   'to',
#   'my',
#   'to',
#   'when',
#   'yes',
#   'you',
#   'i',
#   'to',
#   'dude',
#   'without',
#   'no',
#   'here',
#   'a',
#   'you',
#   'ill',
#   'thank'],
#  'pay': ['attention'],
#  'attention': ['to', 'you'],
#  'world': ['youre', 'you', 'just', 'is', 'and', 'is', 'know', 'these'],
#  'stuck': ['with', 'in'],
#  'shitting': ['all'],
#  'place': ['dont', 'where', 'of', 'and'],
#  'serial': ['killer'],
#  'killer': ['dont'],
#  'touch': ['that', 'my'],
#  'four': ['kids', 'times', 'years', 'you', 'more'],
#  'sentence': ['trying'],
#  'college': ['society', 'step', 'gig', 'you'],
#  'society': ['just'],
#  'keeps': ['fucking', 'going'],
#  'step': ['back'],
#  'happened': ['youre', 'really', 'he', 'was', 'pretty'],
#  'paying': ['attention'],
#  'record': ['collection'],
#  'collection': ['someone'],
#  'sticks': ['a'],
#  'mike': ['in'],
#  'face': ['youre', 'plant', 'all', 'in'],
#  'sad': ['things'],
#  'things': ['about', 'gonna', 'ive'],
#  'passes': ['you'],
#  'passing': ['me', 'me'],
#  'anymore': ['i', 'or', 'all', 'you'],
#  'figure': ['out', 'out', 'if', 'it', 'uh', 'out', 'you', 'it'],
#  'into': ['i',
#   'so',
#   'like',
#   'that',
#   'the',
#   'youre',
#   'but',
#   'that',
#   'albany',
#   'a',
#   'some',
#   'land',
#   'it',
#   'the',
#   'the',
#   'a',
#   'that',
#   'shit'],
#  'senior': ['was'],
#  'dudes': ['are'],
#  'dj': ['music'],
#  'music': ['or', 'you', 'and', 'yeah', 'it'],
#  'ill': ['watch',
#   'get',
#   'say',
#   'say',
#   'start',
#   'just',
#   'just',
#   'just',
#   'just',
#   'whittle',
#   'get',
#   'break',
#   'do',
#   'he',
#   'do',
#   'hang',
#   'watch',
#   'see'],
#  'reference': ['or'],
#  'comic': ['coming'],
#  'monica': ['lewinsky'],
#  'lewinsky': ['is'],
#  'yk': ['is'],
#  'stylus': ['gonna'],
#  'lasted': ['seconds'],
#  'seconds': ['ninety', 'i', 'later', 'of', 'wham', 'before'],
#  'ninety': ['seconds', 'seconds'],
#  'openminded': ['all', 'i'],
#  'ah': ['this', 'son'],
#  'isnt': ['music', 'this', 'this', 'i'],
#  'kid': ['you',
#   'as',
#   'what',
#   'ill',
#   'that',
#   'tip',
#   'just',
#   'which',
#   'im',
#   'that',
#   'one',
#   'that',
#   'that',
#   'be',
#   'has',
#   'would',
#   'right',
#   'five',
#   'thought',
#   'he'],
#  'dressed': ['like'],
#  'sung': ['about'],
#  'devil': ['now'],
#  'ballad': ['every'],
#  'album': ['started'],
#  'started': ['off', 'to', 'shooting', 'having'],
#  'black': ['and'],
#  'guitar': ['solo'],
#  'solo': ['came'],
#  'shits': ['passing'],
#  'transgender': ['athletes'],
#  'athletes': ['i'],
#  'switch': ['around'],
#  'sports': ['fan', 'bra', 'i', 'i'],
#  'fan': ['thats', 'and'],
#  'really': ['new', 'go', 'youre', 'goes', 'need', 'must', 'wanted'],
#  'new': ['concept', 'duck', 'fears', 'york'],
#  'concept': ['to'],
#  'ranked': ['th'],
#  'th': ['in', 'we'],
#  'cut': ['off', 'off'],
#  'bra': ['and', 'you'],
#  'tennis': ['player'],
#  'shoulders': ['that', 'she'],
#  'seem': ['fair'],
#  'fair': ['i', 'to', 'have'],
#  'might': ['be', 'just', 'as', 'be', 'be', 'be', 'be'],
#  'idea': ['but', 'im', 'i', 'yeah'],
#  'hearing': ['rumors'],
#  'rumors': ['like'],
#  'mma': ['you', 'shit'],
#  'nuts': ['that', 'its', 'like', 'but'],
#  'dickless': ['dude'],
#  'beating': ['the'],
#  'christ': ['he', 'you', 'where', 'be', 'you', 'can', 'when', 'youre'],
#  'discarded': ['dick'],
#  'flashlight': ['hold'],
#  'hold': ['still', 'me', 'me'],
#  'ground': ['and', 'sometimes'],
#  'pound': ['is', 'gorilla'],
#  'incredible': ['yeah', 'but'],
#  'moron': ['ya'],
#  'shock': ['said'],
#  'homophobic': ['stuff', 'stuff', 'thing'],
#  'stuff': ['and',
#   'that',
#   'where',
#   'started',
#   'looking',
#   'out',
#   'she',
#   'that',
#   'of'],
#  'believe': ['yeah',
#   'it',
#   'in',
#   'in',
#   'they',
#   'when',
#   'in',
#   'when',
#   'in',
#   'in',
#   'in',
#   'it'],
#  'totally': ['can'],
#  'vegas': ['i'],
#  'benefit': ['of'],
#  'doubt': ['just'],
#  'case': ['are'],
#  'seriously': ['shocked'],
#  'shocked': ['some'],
#  'beard': ['down'],
#  'boat': ['in', 'i', 'why'],
#  'middle': ['of', 'eastern'],
#  'swamp': ['shooting'],
#  'shooting': ['varmints', 'over', 'at'],
#  'varmints': ['like'],
#  'progressive': ['ideas'],
#  'ideas': ['on', 'that'],
#  'samesex': ['marriage'],
#  'marriage': ['yeah', 'theres', 'marriages'],
#  'exactly': ['what'],
#  'kills': ['me', 'me', 'me', 'confirmed', 'theyre', 'me'],
#  'kinda': ['shit', 'like'],
#  'from': ['the',
#   'that',
#   'the',
#   'sunday',
#   'my',
#   'a',
#   'that',
#   'that',
#   'a',
#   'a',
#   'that',
#   'a',
#   'the',
#   'there',
#   'your',
#   'a'],
#  'book': ['all', 'right'],
#  'tried': ['to', 'to'],
#  'update': ['it', 'itunes', 'the'],
#  'itunes': ['every'],
#  'six': ['days', 'of', 'mine', 'mine', 'get'],
#  'days': ['can', 'later', 'la', 'in', 'in', 'in', 'later', 'in'],
#  'language': ['and'],
#  'little': ['more',
#   'plane',
#   'faster',
#   'bit',
#   'and',
#   'but',
#   'kid',
#   'maniac',
#   'boys',
#   'surprise',
#   'queer',
#   'gun',
#   'yellow',
#   'dog',
#   'pushback',
#   'something',
#   'bit',
#   'angel',
#   'bit',
#   'bit',
#   'bit',
#   'bit',
#   'to'],
#  'more': ['user',
#   'complex',
#   'seconds',
#   'seconds',
#   'times',
#   'over',
#   'interesting'],
#  'user': ['friendlieth'],
#  'friendlieth': ['for'],
#  'fault': ['that'],
#  'sunday': ['school', 'school'],
#  'school': ['in', 'and', 'with'],
#  'brainwash': ['you', 'you', 'you'],
#  'clap': ['dont', 'i'],
#  'follow': ['someone'],
#  'else': ['im', 'what', 'like', 'works'],
#  'brains': ['all'],
#  'empty': ['they', 'threat'],
#  'fill': ['it'],
#  'jelly': ['donut'],
#  'donut': ['just'],
#  'toys': ['all', 'right', 'if'],
#  'repeat': ['everything'],
#  'everything': ['they', 'is', 'from', 'okay', 'and', 'doesnt', 'okay', 'else'],
#  'good': ['the', 'boy', 'man', 'morning', 'dentition', 'days', 'but', 'time'],
#  'stick': ['a', 'yeah'],
#  'star': ['on', 'for'],
#  'forehead': ['youre'],
#  'boy': ['looks', 'hes', 'soldier', 'solider', 'you'],
#  'looks': ['like', 'around', 'safe'],
#  'masters': ['degree'],
#  'degree': ['in'],
#  'english': ['like'],
#  'invents': ['the'],
#  'whistle': ['or'],
#  'call': ['it', 'oh', 'them', 'me', 'if'],
#  'yours': ['goes'],
#  'whack': ['whack', 'mine'],
#  'mine': ['goes', 'just', 'just', 'just', 'just'],
#  'whackafuckinwhack': ['dude'],
#  'zillion': ['bucks'],
#  'bucks': ['gets'],
#  'tv': ['show', 'get', 'without', 'she'],
#  'show': ['hes', 'up', 'up', 'up', 'up', 'youre', 'it', 'up'],
#  'loving': ['life'],
#  'nowhere': ['here', 'he', 'we', 'to', 'they'],
#  'sixty': ['years'],
#  'stands': ['up', 'for'],
#  'manchurian': ['candidate'],
#  'candidate': ['jesus', 'will', 'when'],
#  'liked': ['hookers'],
#  'hookers': ['and'],
#  'lepers': ['doesnt'],
#  'queers': ['and'],
#  'freaks': ['the'],
#  'dead': ['oh', 'and', 'like', 'like', 'and', 'like', 'asleep'],
#  'oh': ['whered', 'what', 'fuck', 'all', 'my', 'my', 'my', 'my', 'my', 'my'],
#  'whered': ['everybody'],
#  'scared': ['old', 'im', 'in', 'as'],
#  'yelled': ['at', 'at'],
#  'glaad': ['right'],
#  'forget': ['its'],
#  'lesbian': ['a'],
#  'writing': ['the'],
#  'could': ['you',
#   'do',
#   'it',
#   'come',
#   'fucking',
#   'sit',
#   'still',
#   'hear',
#   'shoot',
#   'defend',
#   'grab'],
#  'please': ['teareth', 'dont', 'dont'],
#  'teareth': ['outeth'],
#  'outeth': ['those'],
#  'coupleth': ['of'],
#  'pages': ['theyre'],
#  'vatican': ['theyre'],
#  'city': ['they', 'theyre', 'that', 'just', 'doesnt', 'like'],
#  'wall': ['around', 'i', 'oh', 'im', 'slides'],
#  'brushing': ['off'],
#  'cases': ['of'],
#  'pedophilia': ['like'],
#  'nothing': ['theyre', 'to'],
#  'taking': ['that', 'drama', 'drama', 'branches', 'back', 'my'],
#  'click': ['they'],
#  'care': ['i', 'he', 'who', 'if', 'the'],
#  'learned': ['a'],
#  'ago': ['i', 'so', 'he'],
#  'walked': ['away', 'on'],
#  'religion': ['i',
#   'made',
#   'basis',
#   'makes',
#   'sounded',
#   'hey',
#   'i',
#   'right',
#   'was',
#   'its',
#   'like'],
#  'lazy': ['i'],
#  'sundays': ['and'],
#  'okay': ['heard',
#   'i',
#   'a',
#   'this',
#   'if',
#   'but',
#   'in',
#   'and',
#   'you',
#   'it',
#   'my',
#   'so',
#   'jesus',
#   'i',
#   'i',
#   'but',
#   'so',
#   'she',
#   'my'],
#  'times': ['the', 'a', 'never'],
#  'hasnt': ['come'],
#  'yet': ['you', 'right'],
#  'mulching': ['over'],
#  'aspect': ['was'],
#  'felt': ['my', 'like', 'like', 'a', 'slighted'],
#  'elses': ['sounded', 'religion'],
#  'sounded': ['stupid', 'stupid'],
#  'basis': ['of', 'of'],
#  'ten': ['commandments', 'minutes'],
#  'commandments': ['dont'],
#  'kill': ['anybody', 'somebody'],
#  'bike': ['right'],
#  'which': ['ive', 'was', 'is', 'is', 'i', 'i', 'i'],
#  'ive': ['broken',
#   'broken',
#   'been',
#   'finally',
#   'been',
#   'ever',
#   'never',
#   'extended',
#   'kind'],
#  'broken': ['i', 'just'],
#  'commandment': ['except'],
#  'except': ['for', 'i'],
#  'fifth': ['one', 'grade'],
#  'havent': ['killed', 'been'],
#  'murderous': ['thoughts'],
#  'thoughts': ['that'],
#  'sometimes': ['i', 'i', 'sometimes', 'i'],
#  'plane': ['and', 'i', 'the', 'and'],
#  'kick': ['off', 'me', 'i'],
#  'loafers': ['and'],
#  'wearing': ['those', 'a', 'a'],
#  'goldtoed': ['like'],
#  'dress': ['socks'],
#  'socks': ['and'],
#  'cross': ['their'],
#  'feet': ['at', 'together', 'going', 'up'],
#  'ankles': ['and'],
#  'rubbing': ['their'],
#  'wrapping': ['that'],
#  'sock': ['shh'],
#  'shh': ['shh', 'shh', 'right'],
#  'los': ['angeles', 'angeles'],
#  'angeles': ['theres', 'yeah'],
#  'scientologists': ['out', 'i'],
#  'story': ['of', 'when', 'when', 'there', 'i', 'down', 'turns', 'im', 'i'],
#  'scientology': ['i'],
#  'name': ['is', 'proud'],
#  'ron': ['ron', 'and'],
#  'alive': ['thousands', 'like'],
#  'thousands': ['of'],
#  'hide': ['a'],
#  'mystery': ['this'],
#  'drivers': ['license'],
#  'license': ['social', 'im'],
#  'social': ['security'],
#  'security': ['number'],
#  'number': ['theres'],
#  'footage': ['of'],
#  'stubbing': ['his'],
#  'toe': ['motherfucker'],
#  'motherfucker': ['right'],
#  'working': ['at'],
#  'dennys': ['he'],
#  'sick': ['of', 'of'],
#  'spaceship': ['coming', 'in'],
#  'sneakers': ['this', 'theres'],
#  'tom': ['cruise'],
#  'cruise': ['were'],
#  'clear': ['right'],
#  'paraphrasing': ['im', 'to', 'but'],
#  'essentially': ['what'],
#  'while': ['simultaneously', 'you', 'we', 'you', 'theyll'],
#  'simultaneously': ['still'],
#  'believing': ['that'],
#  'baby': ['that', 'moonwalking', 'hey'],
#  'total': ['sense'],
#  'theirs': ['you'],
#  'space': ['shuttle'],
#  'shuttle': ['you'],
#  'relate': ['to'],
#  'sound': ['so'],
#  'dumb': ['to', 'sandals'],
#  'adult': ['i', 'and', 'telling', 'where', 'female', 'woman'],
#  'chimney': ['giving'],
#  'giving': ['me', 'the'],
#  'christmas': ['toys'],
#  'lost': ['a'],
#  'tooth': ['there', 'fairy'],
#  'fairy': ['there', 'rabbits'],
#  'easter': ['bunny'],
#  'bunny': ['why'],
#  'wouldnt': ['there', 'burn', 'i', 'send', 'that'],
#  'bearded': ['baby'],
#  'moonwalking': ['across'],
#  'across': ['the', 'and'],
#  'lake': ['throwing'],
#  'throwing': ['out', 'him', 'a'],
#  'bottomless': ['buckets'],
#  'buckets': ['of'],
#  'shrimp': ['or'],
#  'course': ['that'],
#  'son': ['there', 'is', 'you', 'to', 'cant', 'the', 'make', 'keep'],
#  'mother': ['and', 'one', 'to'],
#  'moms': ['the'],
#  'rabbits': ['dont'],
#  'eggs': ['her'],
#  'tits': ['are'],
#  'fake': ['the'],
#  'nba': ['is'],
#  'fixed': ['bankers'],
#  'bankers': ['are'],
#  'cunts': ['most'],
#  'dreams': ['wont', 'arent'],
#  'wow': ['this'],
#  'meanwhile': ['this', 'i', 'some', 'you'],
#  'floating': ['this'],
#  'gorilla': ['of'],
#  'decision': ['what', 'he'],
#  'cling': ['to'],
#  'christians': ['and'],
#  'become': ['that', 'weaker'],
#  'douche': ['all'],
#  'casual': ['christian'],
#  'christian': ['right'],
#  'foot': ['on', 'on', 'belly'],
#  'base': ['just'],
#  'town': ['i', 'i'],
#  'act': ['like', 'to', 'like', 'locally'],
#  'option': ['which'],
#  'creepy': ['moment'],
#  'moment': ['in', 'where'],
#  'curling': ['you'],
#  'shooter': ['or'],
#  'sliding': ['with', 'and'],
#  'rock': ['right', 'just', 'your'],
#  'ride': ['the', 'up'],
#  'team': ['and'],
#  'stops': ['thats', 'and'],
#  'riot': ['act'],
#  'third': ['day', 'grade'],
#  'rose': ['again'],
#  'fulfillment': ['of'],
#  'scriptures': ['i'],
#  'floated': ['away'],
#  'any': ['religion', 'sense', 'complaints', 'kids', 'of', 'of', 'sort'],
#  'unrestricted': ['free'],
#  'free': ['agent'],
#  'agent': ['you'],
#  'asking': ['people'],
#  'able': ['to'],
#  'find': ['anything', 'another', 'the', 'the', 'the'],
#  'helsinki': ['and'],
#  'lutheran': ['and'],
#  'pigeon': ['just'],
#  'layin': ['there'],
#  'blew': ['my', 'and'],
#  'mind': ['im', 'explaining', 'im', 'i', 'them'],
#  'judged': ['right', 'someday'],
#  'pops': ['in'],
#  'dvd': ['of'],
#  'explaining': ['yourself'],
#  'arrogant': ['thing', 'things'],
#  'night': ['but', 'at', 'talking', 'as', 'look', 'she', 'they'],
#  'resent': ['the'],
#  'fact': ['that', 'that', 'that', 'if'],
#  'someday': ['like', 'i', 'youll', 'youll', 'so'],
#  'somebodys': ['gonna', 'head'],
#  'judge': ['me'],
#  'fuckup': ['all'],
#  'turn': ['this', 'around', 'around', 'this', 'around', 'him', 'eight'],
#  'freedom': ['of'],
#  'whores': ['you'],
#  'suck': ['at'],
#  'rails': ['like'],
#  'set': ['me'],
#  'fail': ['and'],
#  'built': ['a', 'it'],
#  'burn': ['it'],
#  'forever': ['you'],
#  'evil': ['piece'],
#  'light': ['it', 'psycho', 'though'],
#  'fire': ['i'],
#  'troubleshoot': ['is'],
#  'engine': ['is'],
#  ...}

# %% [markdown]
# ## Text Generator

# %%
import random

def generate_sentence(chain, count=15):
    # Choosing a random key to start with
    word1 = random.choice(list(chain.keys()))
    # Capitalizing the first word
    sentence = word1.capitalize()
    
    for i in range(count - 1):
        # Choosing the next
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2
        
    sentence += '.'
    return(sentence)

# %%
generate_sentence(bills, 50)
# Out:
# 'Flop in the bed grab a fuck out of how i could defend my wifes always just had he wants you fuck you could hear that guy is going to people my headphones dont know i had a sudden people okay so one of couple of the kitchen table i.'

# %%
generate_sentence(bills, 50)
# Out:
# 'Factory like your mind im like it they wont get along with an original wedding theres candles that shit am immediately the hell she goes whack mine just accidentally did you know when you this dude beating the discovery channel about facebook i figure uh i dont understand that little.'

# %%
generate_sentence(bills, 50)
# Out:
# 'Whores you gonna do you son is fixed bankers are cool drink lemonade was like psychotic with my story down they still some waitress wrote on the female ant pussy for me i shot the planes all over miles of it okay but i was falling out there you got.'
